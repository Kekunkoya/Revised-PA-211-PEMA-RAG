# %% [markdown]
# ## Context-Enriched Retrieval in RAG
# Retrieval-Augmented Generation (RAG) enhances AI responses by retrieving relevant knowledge from external sources. Traditional retrieval methods return isolated text chunks, which can lead to incomplete answers.
#
# To address this, we introduce Context-Enriched Retrieval, which ensures that retrieved information includes neighboring chunks for better coherence.
#
# Steps in This Notebook:
# - Data Ingestion: Extract text from a PDF.
# - Chunking with Overlapping Context: Split text into overlapping chunks to preserve context.
# - Embedding Creation: Convert text chunks into numerical representations.
# - Context-Aware Retrieval: Retrieve relevant chunks along with their neighbors for better completeness.
# - Response Generation: Use a language model to generate responses based on retrieved context.
# - Evaluation: Assess the model's response accuracy.

# %% [markdown]
# ## Setting Up the Environment
# We begin by importing necessary libraries.

# %%
import fitz
import os
import numpy as np
import json
from openai import OpenAI

# %% [markdown]
# ## Extracting Text from a PDF File
# To implement RAG, we first need a source of textual data. In this case, we extract text from a PDF file using the PyMuPDF library.

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts text from a PDF file and prints the first `num_chars` characters.

    Args:
    pdf_path (str): Path to the PDF file.

    Returns:
    str: Extracted text from the PDF.
    """
    # Open the PDF file
    mypdf = fitz.open(pdf_path)
    all_text = ""  # Initialize an empty string to store the extracted text

    # Iterate through each page in the PDF
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]  # Get the page
        text = page.get_text("text")  # Extract text from the page
        all_text += text  # Append the extracted text to the all_text string

    return all_text  # Return the extracted text

# %%
import os
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    """
    Extracts text from a PDF file.
    Args:
        pdf_path (str): Path to the PDF file.
    Returns:
        str: Extracted text from the PDF.
    """
    mypdf = fitz.open(pdf_path)
    all_text = ""
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]
        text = page.get_text("text")
        all_text += text
    return all_text

def extract_texts_from_folder(folder_path):
    """
    Extracts text from all PDF files in a folder (recursively).
    Args:
        folder_path (str): Path to the folder containing PDFs.
    Returns:
        dict: {pdf_path: extracted_text, ...}
    """
    pdf_texts = {}
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith('.pdf'):
                pdf_path = os.path.join(root, file)
                try:
                    pdf_texts[pdf_path] = extract_text_from_pdf(pdf_path)
                except Exception as e:
                    print(f"Failed to extract {pdf_path}: {e}")
    return pdf_texts

# %% [markdown]
# ## Chunking the Extracted Text
# Once we have the extracted text, we divide it into smaller, overlapping chunks to improve retrieval accuracy.

# %%
def chunk_text(text, n, overlap):
    """
    Chunks the given text into segments of n characters with overlap.

    Args:
    text (str): The text to be chunked.
    n (int): The number of characters in each chunk.
    overlap (int): The number of overlapping characters between chunks.

    Returns:
    List[str]: A list of text chunks.
    """
    chunks = []  # Initialize an empty list to store the chunks
    
    # Loop through the text with a step size of (n - overlap)
    for i in range(0, len(text), n - overlap):
        # Append a chunk of text from index i to i + n to the chunks list
        chunks.append(text[i:i + n])

    return chunks  # Return the list of text chunks

# %% [markdown]
# ## Setting Up the OpenAI API Client
# We initialize the OpenAI client to generate embeddings and responses.

# %%
import os
import google.generativeai as genai

# --- Configure Google Generative AI client ---
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    print("Error: GOOGLE_API_KEY environment variable is not set.")
    exit(1)

try:
    genai.configure(api_key=GOOGLE_API_KEY)
except Exception as e:
    print(f"Error configuring Google Generative AI: {e}")
    exit(1)

# --- Initialize models ---
# For chat completions
chat_model = genai.GenerativeModel("gemini-2.0-flash")

# For embeddings
embedding_model = genai.GenerativeModel("text-embedding-004")

# %% [markdown]
# ## Extracting and Chunking Text from a PDF File
# Now, we load the PDF, extract text, and split it into chunks.

# %%
# Define the path to the PDF file
pdf_path = "/Users/kekunkoya/Desktop/RAG Google/PEMA.pdf"

# Extract text from the PDF file
extracted_text = extract_text_from_pdf(pdf_path)

# Chunk the extracted text into segments of 1000 characters with an overlap of 200 characters
text_chunks = chunk_text(extracted_text, 1000, 200)

# Print the number of text chunks created
print("Number of text chunks:", len(text_chunks))

# Print the first text chunk
print("\nFirst text chunk:")
print(text_chunks[0])
# Out:
# Number of text chunks: 69
#
# First text chunk:
# PENNSYLVANIA
# EMERGENCY
# PREPAREDNESS
# GUIDE
# Be Informed. Be Prepared. Be Involved.
# www.Ready.PA.gov
# readypa@pa.gov
# Emergency Preparedness Guide. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Table of Contents
# TABLE OF CONTENTS  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Pages 2-3
# INTRODUCTION . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  Page    4
# TOP 10 EMERGENCIES . . . . . . . . . . . . . . . . . . . . . . Pages 4-7
#
#
#
# Floods • Fires • Winter Storms • Tropical Storms, Tornadoes
# and Thunderstorms • Influenza (Flu) Pandemic • Hazardous
# Material Incidents • Earthquakes and Landslides • Nuclear
# Threat • Dam Failures • Terrorism. . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# BE PREPARED – MAKE A PLAN   .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .    Pages 10-11
# How to Make a Fami

# %%
import os
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    mypdf = fitz.open(pdf_path)
    all_text = ""
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]
        text = page.get_text("text")
        all_text += text
    return all_text

def extract_texts_from_folder(folder_path):
    pdf_texts = {}
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith('.pdf'):
                pdf_path = os.path.join(root, file)
                try:
                    pdf_texts[pdf_path] = extract_text_from_pdf(pdf_path)
                except Exception as e:
                    print(f"Failed to extract {pdf_path}: {e}")
    return pdf_texts

def chunk_text(text, chunk_size=1000, overlap=200):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += chunk_size - overlap
        if start >= len(text):
            break
    return chunks

# ---- Main script ----

# Define the path to the folder containing PDFs
folder_path = "/Users/kekunkoya/Desktop/RAG Google 2/PDFs"

# Extract text from all PDF files in the folder
pdf_texts = extract_texts_from_folder(folder_path)

for pdf_path, extracted_text in pdf_texts.items():
    if not extracted_text.strip():
        print(f"PDF {os.path.basename(pdf_path)} is empty after extraction. Skipping.")
        continue
    text_chunks = chunk_text(extracted_text, 1000, 200)
    print(f"\nPDF: {os.path.basename(pdf_path)}")
    print("Number of text chunks:", len(text_chunks))
    if text_chunks:
        print("First text chunk:")
        print(text_chunks[0][:300])  # Print the first 300 characters for preview
    else:
        print("No text chunks found (possibly an empty or image-only PDF).")
# Out:
# PDF: PA 211 Disaster Community Resources.pdf
# Number of text chunks: 13
# First text chunk:
# PA 211 Community Disaster and Human
# Services Resources in Pennsylvania
# Introduction
#
# Community Disaster and Human Services Resources in Pennsylvania
#
# Disasters, whether natural or man-made, have significant and far-reaching impacts on
# individuals, families, and communities. Pennsylvania, with
#
# PDF: 211 RESPONDS TO URGENT NEEDS.pdf
# Number of text chunks: 7
# First text chunk:
# 211 RESPONDS TO URGENT NEEDS
# FACT
# 211 stood up a statewide text
# response to support employees
# impacted by the partial federal
# government shutdown who did
# not know when they would
# receive their next paycheck.
# 211 assists in times of
# disaster and widespread
# need
# FACT
# FACT
# 1
# PLEASE VOTE TO INCLUDE FUN
#
# PDF: PEMA.pdf
# Number of text chunks: 69
# First text chunk:
# PENNSYLVANIA
# EMERGENCY
# PREPAREDNESS
# GUIDE
# Be Informed. Be Prepared. Be Involved.
# www.Ready.PA.gov
# readypa@pa.gov
# Emergency Preparedness Guide. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# PDF: ready-gov_disaster-preparedness-guide-for-older-adults.pdf
# Number of text chunks: 23
# First text chunk:
# 1
# TAKE
# CONTROL IN
# 1
# 2
# 3
# Disaster Preparedness Guide for Older Adults
#
#
# STEP 1 | ASSESS YOUR NEEDS
# First, know your risk. Then, understand your needs during emergencies.
# This section guides you through a self-assessment process to identify your
# specific needs so that you can create a personaliz
#
# PDF: Substantial Damages Toolkit.pdf
# Number of text chunks: 299
# First text chunk:
#
#
#
# Prepared for:
# Pennsylvania Emergency Management
# Agency
# Emergency Management, Mitigation,
# Insurance, and Resilient Communities
# (MIRC) Office
# 1310 Elmerton Avenue
# Harrisburg, Pennsylvania 17110
# Prepared by:
# PG Environmental and ERG
# 14555 Avion Parkway, Suite 125
# Chantilly, VA 20151

# %% [markdown]
# ## Creating Embeddings for Text Chunks
# Embeddings transform text into numerical vectors, which allow for efficient similarity search.

# %%
def create_embeddings(text, model_name="text-embedding-004"):
    """
    Creates embeddings for the given text using the specified Google AI model.

    Args:
    text (str or list of str): The input text(s) for which embeddings are to be created.
    model_name (str): The model to be used for creating embeddings. Default is "text-embedding-004".

    Returns:
    list: A list of embedding vectors. Returns an empty list on error.
    """
    is_list_input = isinstance(text, list)

    try:
        if is_list_input:
            response = genai.embed_content(model=model_name, content=text, task_type="RETRIEVAL_DOCUMENT")
            return [part['values'] for part in response['embedding']] # Access embedding values
        else:
            response = genai.embed_content(model=model_name, content=[text], task_type="RETRIEVAL_DOCUMENT")
            return response['embedding'][0]['values'] # Access embedding values for single text
    except Exception as e:
        print(f"Error creating embeddings: {e}")
        return [] # Return empty list on error

# Example usage (assuming 'text_chunks' is defined from your PDF processing)
# This part would typically follow the PDF extraction and chunking.
# For this example, we'll use a placeholder if text_chunks isn't available.
# text_chunks = ["Example chunk one.", "Example chunk two."] # Uncomment for testing if text_chunks is not defined

# if 'text_chunks' in locals() and text_chunks:
#     chunk_embeddings = create_embeddings(text_chunks, model_name='text-embedding-004')
#     formatted_chunk_embeddings = [{'embedding': emb} for emb in chunk_embeddings]
#     print(f"Generated {len(formatted_chunk_embeddings)} embeddings.")
# else:
#     print("Warning: 'text_chunks' not found or empty. Cannot generate embeddings without text data.")

# %% [markdown]
# ## Implementing Context-Aware Semantic Search
# We modify retrieval to include neighboring chunks for better context.

# %%
def cosine_similarity(vec1, vec2):
    """
    Calculates the cosine similarity between two vectors.

    Args:
    vec1 (np.ndarray): The first vector.
    vec2 (np.ndarray): The second vector.

    Returns:
    float: The cosine similarity between the two vectors.
    """
    # Compute the dot product of the two vectors and divide by the product of their norms
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
def context_enriched_search(query, text_chunks, embeddings, k=1, context_size=1):
    """
    Retrieves the most relevant chunk along with its neighboring chunks.

    Args:
    query (str): Search query.
    text_chunks (List[str]): List of text chunks.
    embeddings (List[dict]): List of chunk embeddings.
    k (int): Number of relevant chunks to retrieve.
    context_size (int): Number of neighboring chunks to include.

    Returns:
    List[str]: Relevant text chunks with contextual information.
    """
    # Convert the query into an embedding vector
    query_embedding = create_embeddings(query).data[0].embedding
    similarity_scores = []

    # Compute similarity scores between query and each text chunk embedding
    for i, chunk_embedding in enumerate(embeddings):
        # Calculate cosine similarity between the query embedding and current chunk embedding
        similarity_score = cosine_similarity(np.array(query_embedding), np.array(chunk_embedding.embedding))
        # Store the index and similarity score as a tuple
        similarity_scores.append((i, similarity_score))

    # Sort chunks by similarity score in descending order (highest similarity first)
    similarity_scores.sort(key=lambda x: x[1], reverse=True)

    # Get the index of the most relevant chunk
    top_index = similarity_scores[0][0]

    # Define the range for context inclusion
    # Ensure we don't go below 0 or beyond the length of text_chunks
    start = max(0, top_index - context_size)
    end = min(len(text_chunks), top_index + context_size + 1)

    # Return the relevant chunk along with its neighboring context chunks
    return [text_chunks[i] for i in range(start, end)]

# %% [markdown]
# ## Running a Query with Context Retrieval
# We now test the context-enriched retrieval.

# %%
# Corrected Python Code with Fixed f-string Syntax and Imports

import os
import json

# Load the validation dataset from a JSON file
json_file_path = '/Users/kekunkoya/Desktop/RAG Google 2/PA211_expanded_dataset.json'
try:
    with open(json_file_path, 'r') as f:
        data = json.load(f)
except FileNotFoundError:
    print(f"Error: The file '{json_file_path}' was not found.")
    print("Please ensure the path is correct and the file exists.")
    # Create a dummy val.json for demonstration if it doesn't exist
    data = [{"question": "What are resources available for food ?"}]
    os.makedirs(os.path.dirname(json_file_path), exist_ok=True)
    with open(json_file_path, 'w') as f:
        json.dump(data, f)
    print("A dummy 'val.json' file has been created for demonstration purposes.")
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from '{json_file_path}'. Please check file content.")
    data = [{"question": "What is the primary function of embeddings?"}]

# Extract the first question from the dataset to use as our query
if data:
    query = data[0]['question']
else:
    query = "What is the purpose of this code?"
    print("Warning: No questions found in val.json. Using a default query.")

# Placeholder variables for demonstration
text_chunks = ["Chunk A", "Chunk B", "Chunk C"]
response = type("Response", (), {"data": []})()  # Dummy response object

# Retrieve the most relevant chunk and its neighboring chunks for context
# top_chunks = context_enriched_search(query, text_chunks, response.data, k=1, context_size=1)
# For demo purposes, we'll pretend we got one chunk:
top_chunks = ["Example context chunk for query."]

# Print the query for reference
print("\nQuery:", query)

# Print each retrieved chunk with a heading and separator
for i, chunk in enumerate(top_chunks):
    print(f"\n--- Context {i + 1} ---\n{chunk}\n")  # Fixed f-string literal
# Out:
# Query: What steps does the PEMA Disaster Resource Guide recommend for finding emergency food after a natural disaster in Harrisburg (ZIP 17104)?
#
# --- Context 1 ---
# Example context chunk for query.

# %% [markdown]
# ## Generating a Response Using Retrieved Context
# We now generate a response using LLM.

# %%
# Updated Code with Corrected Embedding Handling and f-string

import os
import json

# Placeholder for create_embeddings function
def create_embeddings(text_list):
    """
    Dummy implementation: in real usage, this should call your embedding API
    and return a list of objects with an .embedding attribute.
    """
    class Embedding:
        def __init__(self, vector):
            self.embedding = vector
    # Return dummy embeddings (e.g., zero-vectors)
    return [Embedding([0.0] * 768) for _ in text_list]

# Placeholder for context_enriched_search function
def context_enriched_search(query, text_chunks, chunk_embeddings, k=1, context_size=1):
    """
    Dummy search: returns the first chunk for demonstration.
    """
    return [text_chunks[0]] if text_chunks else []

# Load the validation dataset from a JSON file
json_file_path = '/Users/kekunkoya/Desktop/RAG Google 2/PA211_expanded_dataset.json'
try:
    with open(json_file_path, 'r') as f:
        data = json.load(f)
except FileNotFoundError:
    print(f"Error: The file '{json_file_path}' was not found.")
    print("Please ensure the path is correct and the file exists.")
    # Create a dummy val.json for demonstration if it doesn't exist
    data = [{"question": "What is AI Explainable AI"}]
    os.makedirs(os.path.dirname(json_file_path), exist_ok=True)
    with open(json_file_path, 'w') as f:
        json.dump(data, f)
    print("A dummy 'val.json' file has been created for demonstration purposes.")
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from '{json_file_path}'. Please check file content.")
    data = [{"question": "What is the primary function of embeddings?"}]

# Extract the first question from the dataset to use as our query
if data:
    query = data[0]['question']
else:
    query = "What does the Red Cross and PEMA shelter guide say about bringing pets to emergency shelters in Harrisburg?"
    print("Warning: No questions found in PA211_expanded_dataset.json. Using a default query.")

# Prepare text chunks and their embeddings (placeholder)
text_chunks = ["Chunk A", "Chunk B", "Chunk C"]
chunk_embeddings = create_embeddings(text_chunks)

# Create embedding for the query
query_embedding_obj = create_embeddings([query])[0]  # get first embedding object
query_embedding = query_embedding_obj.embedding

# Retrieve the most relevant chunk and its neighboring chunks for context
top_chunks = context_enriched_search(query, text_chunks, chunk_embeddings, k=1, context_size=1)

# Print the query for reference
print("\nQuery:", query)

# Print each retrieved chunk with a heading and separator using single quotes in f-string
for i, chunk in enumerate(top_chunks):
    print(f'\n--- Context {i + 1} ---\n{chunk}\n=====================================')
# Out:
# Query: What steps does the PEMA Disaster Resource Guide recommend for finding emergency food after a natural disaster in Harrisburg (ZIP 17104)?
#
# --- Context 1 ---
# Chunk A
# =====================================

# %% [markdown]
# ## Evaluating the AI Response
# We compare the AI response with the expected answer and assign a score.

# %%
import time

results = []

for i, item in enumerate(data):
    user_query = item['question']
    true_answer = item['ideal_answer']
    model = genai.GenerativeModel("gemini-2.0-flash")

    # Step 1: Generate AI answer using Gemini, with retry logic
    ai_answer = ""
    while True:
        try:
            ai_gen = model.generate_content(
                user_query,
                generation_config=genai.GenerationConfig(temperature=0)
            )
            ai_answer = ai_gen.text
            break  # If successful, break out of the loop
        except Exception as e:
            if "429" in str(e) or "ResourceExhausted" in str(e):
                print("Quota exceeded. Waiting 65 seconds before retrying...")
                time.sleep(65)  # Wait before retrying (longer than quota window)
            else:
                print(f"Error generating content: {e}")
                ai_answer = ""
                break

    # Step 2: Embedding-based scoring (keep your try/except if using embeddings)
    try:
        score, similarity = evaluate_response(user_query, ai_answer, true_answer)
    except Exception as e:
        print(f"Embedding error: {e}")
        score, similarity = 0, 0.0

    # Step 3: LLM verification
    try:
        llm_score = llm_verify(user_query, ai_answer, true_answer)
    except Exception as e:
        print(f"LLM verification error: {e}")
        llm_score = "N/A"

    # Step 4: Store results
    results.append({
        "query": user_query,
        "ai_answer": ai_answer,
        "true_answer": true_answer,
        "embedding_score": score,
        "similarity": round(similarity, 3),
        "llm_score": llm_score
    })

    # Step 5: Throttle requests to be extra safe
    print(f"Processed {i+1}/{len(data)}. Waiting 5 seconds before next...")
    time.sleep(5)

# --- Save results to file ---
with open("evaluation_results.json", "w") as f:
    json.dump(results, f, indent=2)

print("✅ Evaluation complete! Results saved to evaluation_results.json")
# Out:
# Processed 1/71. Waiting 5 seconds before next...
# Processed 2/71. Waiting 5 seconds before next...
# Processed 3/71. Waiting 5 seconds before next...
# Processed 4/71. Waiting 5 seconds before next...
# Processed 5/71. Waiting 5 seconds before next...
# Processed 6/71. Waiting 5 seconds before next...
# Processed 7/71. Waiting 5 seconds before next...
# Processed 8/71. Waiting 5 seconds before next...
# Processed 9/71. Waiting 5 seconds before next...
# Processed 10/71. Waiting 5 seconds before next...
# Processed 11/71. Waiting 5 seconds before next...
# Processed 12/71. Waiting 5 seconds before next...
# Processed 13/71. Waiting 5 seconds before next...
# Processed 14/71. Waiting 5 seconds before next...
# Processed 15/71. Waiting 5 seconds before next...
# Processed 16/71. Waiting 5 seconds before next...
# Processed 17/71. Waiting 5 seconds before next...
# Processed 18/71. Waiting 5 seconds before next...
# Processed 19/71. Waiting 5 seconds before next...
# Processed 20/71. Waiting 5 seconds before next...
# Processed 21/71. Waiting 5 seconds before next...
# Processed 22/71. Waiting 5 seconds before next...
# Processed 23/71. Waiting 5 seconds before next...
# Processed 24/71. Waiting 5 seconds before next...
# Processed 25/71. Waiting 5 seconds before next...
# Processed 26/71. Waiting 5 seconds before next...
# Processed 27/71. Waiting 5 seconds before next...
# Processed 28/71. Waiting 5 seconds before next...
# Processed 29/71. Waiting 5 seconds before next...
# Processed 30/71. Waiting 5 seconds before next...
# Processed 31/71. Waiting 5 seconds before next...
# Processed 32/71. Waiting 5 seconds before next...
# Processed 33/71. Waiting 5 seconds before next...
# Processed 34/71. Waiting 5 seconds before next...
# Processed 35/71. Waiting 5 seconds before next...
# Processed 36/71. Waiting 5 seconds before next...
# Processed 37/71. Waiting 5 seconds before next...
# Processed 38/71. Waiting 5 seconds before next...
# Processed 39/71. Waiting 5 seconds before next...
# Processed 40/71. Waiting 5 seconds before next...
# Processed 41/71. Waiting 5 seconds before next...
# Processed 42/71. Waiting 5 seconds before next...
# Processed 43/71. Waiting 5 seconds before next...
# Processed 44/71. Waiting 5 seconds before next...
# Processed 45/71. Waiting 5 seconds before next...
# Processed 46/71. Waiting 5 seconds before next...
# Processed 47/71. Waiting 5 seconds before next...
# Processed 48/71. Waiting 5 seconds before next...
# Processed 49/71. Waiting 5 seconds before next...
# Processed 50/71. Waiting 5 seconds before next...
# Processed 51/71. Waiting 5 seconds before next...
# Processed 52/71. Waiting 5 seconds before next...
# Processed 53/71. Waiting 5 seconds before next...
# Processed 54/71. Waiting 5 seconds before next...
# Processed 55/71. Waiting 5 seconds before next...
# Processed 56/71. Waiting 5 seconds before next...
# Processed 57/71. Waiting 5 seconds before next...
# Processed 58/71. Waiting 5 seconds before next...
# Processed 59/71. Waiting 5 seconds before next...
# Processed 60/71. Waiting 5 seconds before next...
# Processed 61/71. Waiting 5 seconds before next...
# Processed 62/71. Waiting 5 seconds before next...
# Processed 63/71. Waiting 5 seconds before next...
# Processed 64/71. Waiting 5 seconds before next...
# Processed 65/71. Waiting 5 seconds before next...
# Processed 66/71. Waiting 5 seconds before next...
# Processed 67/71. Waiting 5 seconds before next...
# Processed 68/71. Waiting 5 seconds before next...
# Processed 69/71. Waiting 5 seconds before next...
# Processed 70/71. Waiting 5 seconds before next...
# Processed 71/71. Waiting 5 seconds before next...
# ✅ Evaluation complete! Results saved to evaluation_results.json

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Print results in a readable table ---
print(f"{'Query':<50} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9}")
print("-" * 90)

for r in results:
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    print(f"{query_preview:<50} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9}")

# --- Optional: Show only incorrect answers ---
print("\n Incorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"- {r['query']}")
# Out:
# Query                                              | Embed Score  | Similarity | LLM Score
# ------------------------------------------------------------------------------------------
# What steps does the PEMA Disaster Resource Guid... | 1            | 0.917      | 0.5
# According to the PA 211 Emergency Resource Manu... | 0.5          | 0.885      | 0
# What shelter options are listed in the PEMA Eme... | 0            | 0.593      | 0
# How does the PEMA guide recommend seniors in Ha... | 0.5          | 0.865      | 0
# Which organizations provide water delivery or p... | 0.5          | 0.788      | 0
# What school or community-based child meal progr... | 0.5          | 0.849      | 0
# Where can culturally appropriate food be access... | 0.5          | 0.859      | 0
# What guidance does PEMA provide on water safety... | 0.5          | 0.848      | 0.5
# How does PA 211 assist individuals needing wate... | 0.5          | 0.879      | 0.5
# What does the Red Cross and PEMA shelter guide ... | 0.5          | 0.872      | 1
# Where are crisis shelters for domestic violence... | 0            | 0.549      | 0
# What are the recommended first aid or urgent ca... | 0.5          | 0.795      | 0.5
# According to the PA 211 Medication Emergency FA... | 0.5          | 0.86       | 0.5
# What mental health hotlines or crisis counselin... | 0.5          | 0.84       | 0.5
# Where does the PEMA Winter Emergency Guide reco... | 0.5          | 0.822      | 0
# How does PA 211 recommend accessing communicati... | 0.5          | 0.856      | 0.5
# What evacuation resources are described for peo... | 0.5          | 0.839      | 0
# According to PEMA Flood Preparedness Resource, ... | 0.5          | 0.751      | 0
# What steps should be taken to file a FEMA disas... | 0.5          | 0.811      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | 1            | 0.922      | 1
# Where can individuals with oxygen tanks or powe... | 0.5          | 0.898      | 0.5
# What instructions does the PEMA Home Damage Ass... | 0.5          | 0.867      | 0.5
# According to the PA 211 Infant and Family Emerg... | 0.5          | 0.89       | 0.5
# Where does the PEMA Community Resource Guide su... | 1            | 0.905      | 0.5
# What options are presented in the PA 211 Disast... | 1            | 0.915      | 0.5
# What steps does the PEMA Disaster Resource Guid... | 1            | 0.917      | 0.5
# According to the PA 211 Emergency Resource Manu... | 0.5          | 0.885      | 0
# What shelter options are listed in the PEMA Eme... | 0            | 0.593      | 0
# How does the PEMA guide recommend seniors in Ha... | 0.5          | 0.865      | 0
# Which organizations provide water delivery or p... | 0.5          | 0.787      | 0
# What school or community-based child meal progr... | 0.5          | 0.849      | 0
# Where can culturally appropriate food be access... | 0.5          | 0.859      | 0
# What guidance does PEMA provide on water safety... | 0.5          | 0.848      | 0.5
# How does PA 211 assist individuals needing wate... | 0.5          | 0.879      | 0.5
# What does the Red Cross and PEMA shelter guide ... | 0.5          | 0.872      | 1
# Where are crisis shelters for domestic violence... | 0            | 0.549      | 0
# What are the recommended first aid or urgent ca... | 0.5          | 0.832      | 0.5
# According to the PA 211 Medication Emergency FA... | 0.5          | 0.87       | 0.5
# What mental health hotlines or crisis counselin... | 0.5          | 0.837      | 0.5
# Where does the PEMA Winter Emergency Guide reco... | 0.5          | 0.822      | 0
# How does PA 211 recommend accessing communicati... | 0.5          | 0.856      | 0.5
# What evacuation resources are described for peo... | 0.5          | 0.839      | 0
# According to PEMA Flood Preparedness Resource, ... | 0.5          | 0.751      | 0
# What steps should be taken to file a FEMA disas... | 0.5          | 0.819      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | 1            | 0.922      | 1
# Where can individuals with oxygen tanks or powe... | 0.5          | 0.896      | 0.5
# What instructions does the PEMA Home Damage Ass... | 0.5          | 0.876      | 1
# According to the PA 211 Infant and Family Emerg... | 0.5          | 0.895      | 0.5
# Where does the PEMA Community Resource Guide su... | 1            | 0.918      | 0.5
# What options are presented in the PA 211 Disast... | 1            | 0.915      | 0.5
# Can I volunteer to help others in a disaster?      | 0.5          | 0.716      | 1
# How can older adults assess their personal need... | 0.5          | 0.843      | 1
# What steps should I take to create a family eme... | 0.5          | 0.771      | 1
# If I have a disability, how can I ensure my eme... | 0.5          | 0.798      | 1
# How can I stay informed during a disaster if I ... | 0.5          | 0.791      | 1
# What should I do if I am unable to evacuate dur... | 0.5          | 0.797      | 1
# What items should older adults include in an em... | 0.5          | 0.766      | 1
# How can older adults engage their support netwo... | 0.5          | 0.708      | 1
# What special steps should older adults in rural... | 0.5          | 0.741      | 1
# Where can I get help building an emergency plan... | 0.5          | 0.803      | 1
# How can I include my pet or service animal in m... | 0.5          | 0.817      | 1
# How can older adults assess their personal need... | 0.5          | 0.843      | 1
# What steps should I take to create a family eme... | 0.5          | 0.789      | 1
# If I have a disability, how can I ensure my eme... | 0.5          | 0.814      | 1
# How can I stay informed during a disaster if I ... | 0.5          | 0.791      | 1
# What should I do if I am unable to evacuate dur... | 0.5          | 0.797      | 1
# What items should older adults include in an em... | 0.5          | 0.753      | 1
# How can older adults engage their support netwo... | 0.5          | 0.708      | 1
# What special steps should older adults in rural... | 0.5          | 0.758      | 1
# Where can I get help building an emergency plan... | 0.5          | 0.803      | 1
# How can I include my pet or service animal in m... | 0.5          | 0.817      | 1
#
#  Incorrect answers (Embed Score = 0):
# - What shelter options are listed in the PEMA Emergency Shelter Directory for residents in the 17104 area code during severe weather?
# - Where are crisis shelters for domestic violence survivors during disasters, as referenced in the PA 211 Crisis Response and Shelter Services document?
# - What shelter options are listed in the PEMA Emergency Shelter Directory for residents in the 17104 area code during severe weather?
# - Where are crisis shelters for domestic violence survivors during disasters, as referenced in the PA 211 Crisis Response and Shelter Services document?

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Print results in a readable table ---
print(f"{'Query':<50} | {'AI Response':<60} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9}")
print("-" * 150)

for r in results:
    # Truncate long query and AI response for display
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    ai_preview = (r['ai_answer'][:57] + "...") if len(r['ai_answer']) > 60 else r['ai_answer']

    print(f"{query_preview:<50} | {ai_preview:<60} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9}")

# --- Optional: Show only incorrect answers with details ---
print("\n  Incorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"\nQ: {r['query']}")
        print(f"AI: {r['ai_answer']}")
        print(f"TRUE: {r['true_answer']}")
# Out:
# Query                                              | AI Response                                                  | Embed Score  | Similarity | LLM Score
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# What steps does the PEMA Disaster Resource Guid... | I do not have access to the internet to get the most up-t... | 1            | 0.917      | 0.5
# According to the PA 211 Emergency Resource Manu... | I am sorry, but I do not have access to the PA 211 Emerge... | 0.5          | 0.885      | 0
# What shelter options are listed in the PEMA Eme... | I am sorry, I do not have access to the internet to get t... | 0            | 0.593      | 0
# How does the PEMA guide recommend seniors in Ha... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.865      | 0
# Which organizations provide water delivery or p... | I am sorry, but I do not have access to the PA 211 Resour... | 0.5          | 0.788      | 0
# What school or community-based child meal progr... | I am sorry, but I do not have access to specific details ... | 0.5          | 0.849      | 0
# Where can culturally appropriate food be access... | I am sorry, but I do not have access to the internet and ... | 0.5          | 0.859      | 0
# What guidance does PEMA provide on water safety... | I am unable to access real-time information, including sp... | 0.5          | 0.848      | 0.5
# How does PA 211 assist individuals needing wate... | PA 211's Special Needs Preparedness Guide outlines how th... | 0.5          | 0.879      | 0.5
# What does the Red Cross and PEMA shelter guide ... | Okay, let's break down what the Red Cross and PEMA (Penns... | 0.5          | 0.872      | 1
# Where are crisis shelters for domestic violence... | I am sorry, but I do not have access to the internet to g... | 0            | 0.549      | 0
# What are the recommended first aid or urgent ca... | Okay, I've reviewed the PEMA Emergency Medical Resources ... | 0.5          | 0.795      | 0.5
# According to the PA 211 Medication Emergency FA... | According to the PA 211 Medication Emergency FAQ, individ... | 0.5          | 0.86       | 0.5
# What mental health hotlines or crisis counselin... | I do not have access to the PA 211 Emergency Manual or an... | 0.5          | 0.84       | 0.5
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide does not specifically rec... | 0.5          | 0.822      | 0
# How does PA 211 recommend accessing communicati... | PA 211's Disaster Communication Toolkit emphasizes the im... | 0.5          | 0.856      | 0.5
# What evacuation resources are described for peo... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.839      | 0
# According to PEMA Flood Preparedness Resource, ... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.751      | 0
# What steps should be taken to file a FEMA disas... | Okay, while I don't have direct access to a specific "PEM... | 0.5          | 0.811      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | Yes, generally speaking, PA 211 information and resources... | 1            | 0.922      | 1
# Where can individuals with oxygen tanks or powe... | According to the PEMA Special Medical Needs Manual, indiv... | 0.5          | 0.898      | 0.5
# What instructions does the PEMA Home Damage Ass... | The PEMA (Pennsylvania Emergency Management Agency) Home ... | 0.5          | 0.867      | 0.5
# According to the PA 211 Infant and Family Emerg... | According to the PA 211 Infant and Family Emergency Assis... | 0.5          | 0.89       | 0.5
# Where does the PEMA Community Resource Guide su... | The PEMA Community Resource Guide suggests the following ... | 1            | 0.905      | 0.5
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ offers the following opt... | 1            | 0.915      | 0.5
# What steps does the PEMA Disaster Resource Guid... | I do not have access to the internet to get the most up-t... | 1            | 0.917      | 0.5
# According to the PA 211 Emergency Resource Manu... | I am sorry, but I do not have access to the PA 211 Emerge... | 0.5          | 0.885      | 0
# What shelter options are listed in the PEMA Eme... | I am sorry, I do not have access to the internet to get t... | 0            | 0.593      | 0
# How does the PEMA guide recommend seniors in Ha... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.865      | 0
# Which organizations provide water delivery or p... | I am sorry, but I do not have access to the PA 211 Resour... | 0.5          | 0.787      | 0
# What school or community-based child meal progr... | I am sorry, but I do not have access to specific details ... | 0.5          | 0.849      | 0
# Where can culturally appropriate food be access... | I am sorry, but I do not have access to the internet and ... | 0.5          | 0.859      | 0
# What guidance does PEMA provide on water safety... | I am unable to access real-time information, including sp... | 0.5          | 0.848      | 0.5
# How does PA 211 assist individuals needing wate... | PA 211's Special Needs Preparedness Guide outlines how th... | 0.5          | 0.879      | 0.5
# What does the Red Cross and PEMA shelter guide ... | Okay, let's break down what the Red Cross and PEMA (Penns... | 0.5          | 0.872      | 1
# Where are crisis shelters for domestic violence... | I am sorry, but I do not have access to the internet to g... | 0            | 0.549      | 0
# What are the recommended first aid or urgent ca... | Okay, I've reviewed the PEMA (Pennsylvania Emergency Mana... | 0.5          | 0.832      | 0.5
# According to the PA 211 Medication Emergency FA... | According to the PA 211 Medication Emergency FAQ, individ... | 0.5          | 0.87       | 0.5
# What mental health hotlines or crisis counselin... | I do not have access to the PA 211 Emergency Manual or an... | 0.5          | 0.837      | 0.5
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide does not specifically rec... | 0.5          | 0.822      | 0
# How does PA 211 recommend accessing communicati... | PA 211's Disaster Communication Toolkit emphasizes the im... | 0.5          | 0.856      | 0.5
# What evacuation resources are described for peo... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.839      | 0
# According to PEMA Flood Preparedness Resource, ... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.751      | 0
# What steps should be taken to file a FEMA disas... | Okay, while I don't have direct access to a specific "PEM... | 0.5          | 0.819      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | Yes, generally speaking, PA 211 information and resources... | 1            | 0.922      | 1
# Where can individuals with oxygen tanks or powe... | According to the PEMA Special Medical Needs Manual, indiv... | 0.5          | 0.896      | 0.5
# What instructions does the PEMA Home Damage Ass... | The PEMA (Pennsylvania Emergency Management Agency) Home ... | 0.5          | 0.876      | 1
# According to the PA 211 Infant and Family Emerg... | According to the PA 211 Infant and Family Emergency Assis... | 0.5          | 0.895      | 0.5
# Where does the PEMA Community Resource Guide su... | According to the PEMA Community Resource Guide, if home u... | 1            | 0.918      | 0.5
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ offers the following opt... | 1            | 0.915      | 0.5
# Can I volunteer to help others in a disaster?      | Yes, absolutely! Volunteering to help others in a disaste... | 0.5          | 0.716      | 1
# How can older adults assess their personal need... | Older adults can assess their personal needs before a dis... | 0.5          | 0.843      | 1
# What steps should I take to create a family eme... | Creating a family emergency communication plan is crucial... | 0.5          | 0.771      | 1
# If I have a disability, how can I ensure my eme... | Making your emergency kit accessible when you have a disa... | 0.5          | 0.798      | 1
# How can I stay informed during a disaster if I ... | Even without a smartphone, you can still stay informed du... | 0.5          | 0.791      | 1
# What should I do if I am unable to evacuate dur... | Being unable to evacuate during an emergency is a scary s... | 0.5          | 0.797      | 1
# What items should older adults include in an em... | An emergency preparedness kit for older adults should be ... | 0.5          | 0.766      | 1
# How can older adults engage their support netwo... | Older adults can effectively engage their support network... | 0.5          | 0.708      | 1
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0.5          | 0.741      | 1
# Where can I get help building an emergency plan... | It's great that you're thinking about emergency preparedn... | 0.5          | 0.803      | 1
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.817      | 1
# How can older adults assess their personal need... | Older adults can assess their personal needs before a dis... | 0.5          | 0.843      | 1
# What steps should I take to create a family eme... | Creating a family emergency communication plan is crucial... | 0.5          | 0.789      | 1
# If I have a disability, how can I ensure my eme... | Making your emergency kit accessible when you have a disa... | 0.5          | 0.814      | 1
# How can I stay informed during a disaster if I ... | Even without a smartphone, you can still stay informed du... | 0.5          | 0.791      | 1
# What should I do if I am unable to evacuate dur... | Being unable to evacuate during an emergency is a scary s... | 0.5          | 0.797      | 1
# What items should older adults include in an em... | An emergency preparedness kit for older adults should be ... | 0.5          | 0.753      | 1
# How can older adults engage their support netwo... | Older adults can effectively engage their support network... | 0.5          | 0.708      | 1
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0.5          | 0.758      | 1
# Where can I get help building an emergency plan... | It's great that you're thinking about emergency preparedn... | 0.5          | 0.803      | 1
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.817      | 1
#
#   Incorrect answers (Embed Score = 0):
#
# Q: What shelter options are listed in the PEMA Emergency Shelter Directory for residents in the 17104 area code during severe weather?
# AI: I am sorry, I do not have access to the internet to get the information you are requesting.
# TRUE: The PEMA Emergency Shelter Directory lists the Salvation Army Capital City Region (506 S 29th St, Harrisburg), the Harrisburg YMCA, and Red Cross partner shelters as primary options for residents in ZIP 17104. Additional temporary shelters may be opened in public schools and faith-based centers during severe weather emergencies.
#
# Q: Where are crisis shelters for domestic violence survivors during disasters, as referenced in the PA 211 Crisis Response and Shelter Services document?
# AI: I am sorry, but I do not have access to the internet to get the information you are requesting.
# TRUE: The PA 211 Crisis Response and Shelter Services document lists YWCA Safe Haven as a 24/7 secure shelter for domestic violence survivors in Harrisburg, with transportation and trauma support available during disasters.
#
# Q: What shelter options are listed in the PEMA Emergency Shelter Directory for residents in the 17104 area code during severe weather?
# AI: I am sorry, I do not have access to the internet to get the information you are requesting.
# TRUE: The PEMA Emergency Shelter Directory lists the Salvation Army Capital City Region (506 S 29th St, Harrisburg), the Harrisburg YMCA, and Red Cross partner shelters as primary options for residents in ZIP 17104. Additional temporary shelters may be opened in public schools and faith-based centers during severe weather emergencies.
#
# Q: Where are crisis shelters for domestic violence survivors during disasters, as referenced in the PA 211 Crisis Response and Shelter Services document?
# AI: I am sorry, but I do not have access to the internet to get the information you are requesting.
# TRUE: The PA 211 Crisis Response and Shelter Services document lists YWCA Safe Haven as a 24/7 secure shelter for domestic violence survivors in Harrisburg, with transportation and trauma support available during disasters.

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Add a new 'error' field to each result ---
for r in results:
    # We'll define an error as any response that isn't a perfect match (score < 1)
    r['error'] = 'Yes' if r['embedding_score'] < 1 else 'No'

# --- Print results in a readable table with the new 'Error' column ---
print(f"{'Query':<50} | {'AI Response':<60} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9} | {'Error':<5}")
print("-" * 170)

for r in results:
    # Truncate long query and AI response for display
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    ai_preview = (r['ai_answer'][:57] + "...") if len(r['ai_answer']) > 60 else r['ai_answer']

    print(f"{query_preview:<50} | {ai_preview:<60} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9} | {r['error']:<5}")

# --- Optional: Show only incorrect answers with details ---
print("\nIncorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"\nQ: {r['query']}")
        print(f"AI: {r['ai_answer']}")
        print(f"TRUE: {r['true_answer']}")
# Out:
# Query                                              | AI Response                                                  | Embed Score  | Similarity | LLM Score | Error
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# What steps does the PEMA Disaster Resource Guid... | I do not have access to the internet to get the most up-t... | 1            | 0.917      | 0.5       | No
# According to the PA 211 Emergency Resource Manu... | I am sorry, but I do not have access to the PA 211 Emerge... | 0.5          | 0.885      | 0         | Yes
# What shelter options are listed in the PEMA Eme... | I am sorry, I do not have access to the internet to get t... | 0            | 0.593      | 0         | Yes
# How does the PEMA guide recommend seniors in Ha... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.865      | 0         | Yes
# Which organizations provide water delivery or p... | I am sorry, but I do not have access to the PA 211 Resour... | 0.5          | 0.788      | 0         | Yes
# What school or community-based child meal progr... | I am sorry, but I do not have access to specific details ... | 0.5          | 0.849      | 0         | Yes
# Where can culturally appropriate food be access... | I am sorry, but I do not have access to the internet and ... | 0.5          | 0.859      | 0         | Yes
# What guidance does PEMA provide on water safety... | I am unable to access real-time information, including sp... | 0.5          | 0.848      | 0.5       | Yes
# How does PA 211 assist individuals needing wate... | PA 211's Special Needs Preparedness Guide outlines how th... | 0.5          | 0.879      | 0.5       | Yes
# What does the Red Cross and PEMA shelter guide ... | Okay, let's break down what the Red Cross and PEMA (Penns... | 0.5          | 0.872      | 1         | Yes
# Where are crisis shelters for domestic violence... | I am sorry, but I do not have access to the internet to g... | 0            | 0.549      | 0         | Yes
# What are the recommended first aid or urgent ca... | Okay, I've reviewed the PEMA Emergency Medical Resources ... | 0.5          | 0.795      | 0.5       | Yes
# According to the PA 211 Medication Emergency FA... | According to the PA 211 Medication Emergency FAQ, individ... | 0.5          | 0.86       | 0.5       | Yes
# What mental health hotlines or crisis counselin... | I do not have access to the PA 211 Emergency Manual or an... | 0.5          | 0.84       | 0.5       | Yes
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide does not specifically rec... | 0.5          | 0.822      | 0         | Yes
# How does PA 211 recommend accessing communicati... | PA 211's Disaster Communication Toolkit emphasizes the im... | 0.5          | 0.856      | 0.5       | Yes
# What evacuation resources are described for peo... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.839      | 0         | Yes
# According to PEMA Flood Preparedness Resource, ... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.751      | 0         | Yes
# What steps should be taken to file a FEMA disas... | Okay, while I don't have direct access to a specific "PEM... | 0.5          | 0.811      | 0.5       | Yes
# Does the PA 211 Disaster Support Guide indicate... | Yes, generally speaking, PA 211 information and resources... | 1            | 0.922      | 1         | No
# Where can individuals with oxygen tanks or powe... | According to the PEMA Special Medical Needs Manual, indiv... | 0.5          | 0.898      | 0.5       | Yes
# What instructions does the PEMA Home Damage Ass... | The PEMA (Pennsylvania Emergency Management Agency) Home ... | 0.5          | 0.867      | 0.5       | Yes
# According to the PA 211 Infant and Family Emerg... | According to the PA 211 Infant and Family Emergency Assis... | 0.5          | 0.89       | 0.5       | Yes
# Where does the PEMA Community Resource Guide su... | The PEMA Community Resource Guide suggests the following ... | 1            | 0.905      | 0.5       | No
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ offers the following opt... | 1            | 0.915      | 0.5       | No
# What steps does the PEMA Disaster Resource Guid... | I do not have access to the internet to get the most up-t... | 1            | 0.917      | 0.5       | No
# According to the PA 211 Emergency Resource Manu... | I am sorry, but I do not have access to the PA 211 Emerge... | 0.5          | 0.885      | 0         | Yes
# What shelter options are listed in the PEMA Eme... | I am sorry, I do not have access to the internet to get t... | 0            | 0.593      | 0         | Yes
# How does the PEMA guide recommend seniors in Ha... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.865      | 0         | Yes
# Which organizations provide water delivery or p... | I am sorry, but I do not have access to the PA 211 Resour... | 0.5          | 0.787      | 0         | Yes
# What school or community-based child meal progr... | I am sorry, but I do not have access to specific details ... | 0.5          | 0.849      | 0         | Yes
# Where can culturally appropriate food be access... | I am sorry, but I do not have access to the internet and ... | 0.5          | 0.859      | 0         | Yes
# What guidance does PEMA provide on water safety... | I am unable to access real-time information, including sp... | 0.5          | 0.848      | 0.5       | Yes
# How does PA 211 assist individuals needing wate... | PA 211's Special Needs Preparedness Guide outlines how th... | 0.5          | 0.879      | 0.5       | Yes
# What does the Red Cross and PEMA shelter guide ... | Okay, let's break down what the Red Cross and PEMA (Penns... | 0.5          | 0.872      | 1         | Yes
# Where are crisis shelters for domestic violence... | I am sorry, but I do not have access to the internet to g... | 0            | 0.549      | 0         | Yes
# What are the recommended first aid or urgent ca... | Okay, I've reviewed the PEMA (Pennsylvania Emergency Mana... | 0.5          | 0.832      | 0.5       | Yes
# According to the PA 211 Medication Emergency FA... | According to the PA 211 Medication Emergency FAQ, individ... | 0.5          | 0.87       | 0.5       | Yes
# What mental health hotlines or crisis counselin... | I do not have access to the PA 211 Emergency Manual or an... | 0.5          | 0.837      | 0.5       | Yes
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide does not specifically rec... | 0.5          | 0.822      | 0         | Yes
# How does PA 211 recommend accessing communicati... | PA 211's Disaster Communication Toolkit emphasizes the im... | 0.5          | 0.856      | 0.5       | Yes
# What evacuation resources are described for peo... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.839      | 0         | Yes
# According to PEMA Flood Preparedness Resource, ... | I am sorry, but I do not have access to the internet to g... | 0.5          | 0.751      | 0         | Yes
# What steps should be taken to file a FEMA disas... | Okay, while I don't have direct access to a specific "PEM... | 0.5          | 0.819      | 0.5       | Yes
# Does the PA 211 Disaster Support Guide indicate... | Yes, generally speaking, PA 211 information and resources... | 1            | 0.922      | 1         | No
# Where can individuals with oxygen tanks or powe... | According to the PEMA Special Medical Needs Manual, indiv... | 0.5          | 0.896      | 0.5       | Yes
# What instructions does the PEMA Home Damage Ass... | The PEMA (Pennsylvania Emergency Management Agency) Home ... | 0.5          | 0.876      | 1         | Yes
# According to the PA 211 Infant and Family Emerg... | According to the PA 211 Infant and Family Emergency Assis... | 0.5          | 0.895      | 0.5       | Yes
# Where does the PEMA Community Resource Guide su... | According to the PEMA Community Resource Guide, if home u... | 1            | 0.918      | 0.5       | No
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ offers the following opt... | 1            | 0.915      | 0.5       | No
# Can I volunteer to help others in a disaster?      | Yes, absolutely! Volunteering to help others in a disaste... | 0.5          | 0.716      | 1         | Yes
# How can older adults assess their personal need... | Older adults can assess their personal needs before a dis... | 0.5          | 0.843      | 1         | Yes
# What steps should I take to create a family eme... | Creating a family emergency communication plan is crucial... | 0.5          | 0.771      | 1         | Yes
# If I have a disability, how can I ensure my eme... | Making your emergency kit accessible when you have a disa... | 0.5          | 0.798      | 1         | Yes
# How can I stay informed during a disaster if I ... | Even without a smartphone, you can still stay informed du... | 0.5          | 0.791      | 1         | Yes
# What should I do if I am unable to evacuate dur... | Being unable to evacuate during an emergency is a scary s... | 0.5          | 0.797      | 1         | Yes
# What items should older adults include in an em... | An emergency preparedness kit for older adults should be ... | 0.5          | 0.766      | 1         | Yes
# How can older adults engage their support netwo... | Older adults can effectively engage their support network... | 0.5          | 0.708      | 1         | Yes
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0.5          | 0.741      | 1         | Yes
# Where can I get help building an emergency plan... | It's great that you're thinking about emergency preparedn... | 0.5          | 0.803      | 1         | Yes
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.817      | 1         | Yes
# How can older adults assess their personal need... | Older adults can assess their personal needs before a dis... | 0.5          | 0.843      | 1         | Yes
# What steps should I take to create a family eme... | Creating a family emergency communication plan is crucial... | 0.5          | 0.789      | 1         | Yes
# If I have a disability, how can I ensure my eme... | Making your emergency kit accessible when you have a disa... | 0.5          | 0.814      | 1         | Yes
# How can I stay informed during a disaster if I ... | Even without a smartphone, you can still stay informed du... | 0.5          | 0.791      | 1         | Yes
# What should I do if I am unable to evacuate dur... | Being unable to evacuate during an emergency is a scary s... | 0.5          | 0.797      | 1         | Yes
# What items should older adults include in an em... | An emergency preparedness kit for older adults should be ... | 0.5          | 0.753      | 1         | Yes
# How can older adults engage their support netwo... | Older adults can effectively engage their support network... | 0.5          | 0.708      | 1         | Yes
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0.5          | 0.758      | 1         | Yes
# Where can I get help building an emergency plan... | It's great that you're thinking about emergency preparedn... | 0.5          | 0.803      | 1         | Yes
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.817      | 1         | Yes
#
# Incorrect answers (Embed Score = 0):
#
# Q: What shelter options are listed in the PEMA Emergency Shelter Directory for residents in the 17104 area code during severe weather?
# AI: I am sorry, I do not have access to the internet to get the information you are requesting.
# TRUE: The PEMA Emergency Shelter Directory lists the Salvation Army Capital City Region (506 S 29th St, Harrisburg), the Harrisburg YMCA, and Red Cross partner shelters as primary options for residents in ZIP 17104. Additional temporary shelters may be opened in public schools and faith-based centers during severe weather emergencies.
#
# Q: Where are crisis shelters for domestic violence survivors during disasters, as referenced in the PA 211 Crisis Response and Shelter Services document?
# AI: I am sorry, but I do not have access to the internet to get the information you are requesting.
# TRUE: The PA 211 Crisis Response and Shelter Services document lists YWCA Safe Haven as a 24/7 secure shelter for domestic violence survivors in Harrisburg, with transportation and trauma support available during disasters.
#
# Q: What shelter options are listed in the PEMA Emergency Shelter Directory for residents in the 17104 area code during severe weather?
# AI: I am sorry, I do not have access to the internet to get the information you are requesting.
# TRUE: The PEMA Emergency Shelter Directory lists the Salvation Army Capital City Region (506 S 29th St, Harrisburg), the Harrisburg YMCA, and Red Cross partner shelters as primary options for residents in ZIP 17104. Additional temporary shelters may be opened in public schools and faith-based centers during severe weather emergencies.
#
# Q: Where are crisis shelters for domestic violence survivors during disasters, as referenced in the PA 211 Crisis Response and Shelter Services document?
# AI: I am sorry, but I do not have access to the internet to get the information you are requesting.
# TRUE: The PA 211 Crisis Response and Shelter Services document lists YWCA Safe Haven as a 24/7 secure shelter for domestic violence survivors in Harrisburg, with transportation and trauma support available during disasters.
