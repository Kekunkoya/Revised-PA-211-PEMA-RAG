# %% [markdown]
# ## Context-Enriched Retrieval in RAG
# Retrieval-Augmented Generation (RAG) enhances AI responses by retrieving relevant knowledge from external sources. Traditional retrieval methods return isolated text chunks, which can lead to incomplete answers.
#
# To address this, we introduce Context-Enriched Retrieval, which ensures that retrieved information includes neighboring chunks for better coherence.
#
# Steps in This Notebook:
# - Data Ingestion: Extract text from a PDF.
# - Chunking with Overlapping Context: Split text into overlapping chunks to preserve context.
# - Embedding Creation: Convert text chunks into numerical representations.
# - Context-Aware Retrieval: Retrieve relevant chunks along with their neighbors for better completeness.
# - Response Generation: Use a language model to generate responses based on retrieved context.
# - Evaluation: Assess the model's response accuracy.

# %% [markdown]
# ## Setting Up the Environment
# We begin by importing necessary libraries.

# %%
import fitz
import os
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
import numpy as np
import json
from openai import OpenAI

# %% [markdown]
# ## Extracting Text from a PDF File
# To implement RAG, we first need a source of textual data. In this case, we extract text from a PDF file using the PyMuPDF library.

# %%
import os
import fitz  # pip install PyMuPDF

def extract_text_from_pdf(pdf_path: str) -> str:
    """
    Extracts text from a PDF file.
    Args:
        pdf_path (str): Path to the PDF file.
    Returns:
        str: Extracted text from the entire PDF.
    """
    doc = fitz.open(pdf_path)
    all_text = []
    for page in doc:
        all_text.append(page.get_text("text"))
    doc.close()
    return "\n".join(all_text)

def extract_texts_from_folder(pdf_folder: str):
    """
    Extracts text from all PDF files in a folder.
    Args:
        pdf_folder (str): Path to the folder containing PDFs.
    Returns:
        dict: {filename: extracted_text}
    """
    results = {}
    for filename in os.listdir(pdf_folder):
        if filename.lower().endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, filename)
            results[filename] = extract_text_from_pdf(pdf_path)
    return results

# Example usage:
pdf_folder = '/Users/kekunkoya/Desktop/Revised RAG Project/PDFs' 
all_texts = extract_texts_from_folder(pdf_folder)

# Print the first 500 characters of each PDF's extracted text
for fname, text in all_texts.items():
    print(f"--- {fname} ---")
    print(text[:500])
    print("-" * 40)
# Out:
# --- PA 211 Disaster Community Resources.pdf ---
# PA 211 Community Disaster and Human
# Services Resources in Pennsylvania
# Introduction
#
# Community Disaster and Human Services Resources in Pennsylvania
#
# Disasters, whether natural or man-made, have significant and far-reaching impacts on
# individuals, families, and communities. Pennsylvania, with its mix of urban, suburban, and
# rural regions, faces a diverse array of emergencies ranging from floods and severe storms to
# public health crises and housing instability. To ensure an effective res
# ----------------------------------------
# --- 211 RESPONDS TO URGENT NEEDS.pdf ---
# 211 RESPONDS TO URGENT NEEDS
# FACT
# 211 stood up a statewide text
# response to support employees
# impacted by the partial federal
# government shutdown who did
# not know when they would
# receive their next paycheck.
# 211 assists in times of
# disaster and widespread
# need
# FACT
# FACT
# 1
# PLEASE VOTE TO INCLUDE FUNDING FOR PENNSYLVANIA'S 211 SYSTEM IN THE STATE BUDGET TO
# SUPPORT 211'S CAPACITY TO HELP OUR COMMUNITIES IN TIMES OF DISASTER OR GREAT NEED.
# 1 2-1-1 Data
# In January 2019, 187 individuals
# subscribed to
# ----------------------------------------
# --- PEMA.pdf ---
# PENNSYLVANIA
# EMERGENCY
# PREPAREDNESS
# GUIDE
# Be Informed. Be Prepared. Be Involved.
# www.Ready.PA.gov
# readypa@pa.gov
#
# Emergency Preparedness Guide. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Table of Contents
# TABLE OF CONTENTS  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Pages 2-3
# INTRODUCTION . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  Page
# ----------------------------------------
# --- ready-gov_disaster-preparedness-guide-for-older-adults.pdf ---
# 1
# TAKE
# CONTROL IN
# 1
# 2
# 3
# Disaster Preparedness Guide for Older Adults
#
#
#
# STEP 1 | ASSESS YOUR NEEDS
# First, know your risk. Then, understand your needs during emergencies.
# This section guides you through a self-assessment process to identify your
# specific needs so that you can create a personalized emergency plan.
# STEP 2 | MAKE A PLAN
# Develop a comprehensive emergency plan and emergency
# preparedness kit tailored to your unique needs. This section ensures
# you are well prepared to respond to
# ----------------------------------------
# --- Substantial Damages Toolkit.pdf ---
#
#
#
# Prepared for:
# Pennsylvania Emergency Management
# Agency
# Emergency Management, Mitigation,
# Insurance, and Resilient Communities
# (MIRC) Office
# 1310 Elmerton Avenue
# Harrisburg, Pennsylvania 17110
# Prepared by:
# PG Environmental and ERG
# 14555 Avion Parkway, Suite 125
# Chantilly, VA 20151
#
# Substantial Improvements /
# Substantial Damages Toolkit
# APRIL 2023
#
#
# ii
#
# Contents
# Introduction ................................................................................................
# ----------------------------------------

# %% [markdown]
# Using Fritz to extract the text from the PDF, and printing out the first 500 text

# %% [markdown]
# ## Chunking the Extracted Text
# Once we have the extracted text, we divide it into smaller, overlapping chunks to improve retrieval accuracy.

# %%
def chunk_text(text, n, overlap):
    """
    Chunks the given text into segments of n characters with overlap.

    Args:
    text (str): The text to be chunked.
    n (int): The number of characters in each chunk.
    overlap (int): The number of overlapping characters between chunks.

    Returns:
    List[str]: A list of text chunks.
    """
    chunks = []  # Initialize an empty list to store the chunks
    
    # Loop through the text with a step size of (n - overlap)
    for i in range(0, len(text), n - overlap):
        # Append a chunk of text from index i to i + n to the chunks list
        chunks.append(text[i:i + n])

    return chunks  # Return the list of text chunks

# %% [markdown]
# ## Setting Up the OpenAI API Client
# We initialize the OpenAI client to generate embeddings and responses.

# %%
# Initialize the OpenAI client with the base URL and API key
client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")  # Retrieve the API key from environment variables
)

# %% [markdown]
# ## Extracting and Chunking Text from a PDF File
# Now, we load the PDF, extract text, and split it into chunks.

# %%
import os
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    all_text = []
    for page in doc:
        all_text.append(page.get_text("text"))
    doc.close()
    return "\n".join(all_text)

def chunk_text(text, chunk_size=1000, overlap=200):
    chunks = []
    start = 0
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

# --- Updated logic: Process ALL PDFs in a folder ---

pdf_folder = "/Users/kekunkoya/Desktop/Revised RAG Project/PDFs"  

for filename in os.listdir(pdf_folder):
    if filename.lower().endswith('.pdf'):
        pdf_path = os.path.join(pdf_folder, filename)
        extracted_text = extract_text_from_pdf(pdf_path)
        text_chunks = chunk_text(extracted_text, 1000, 200)
        print(f"\n--- {filename} ---")
        print("Number of text chunks:", len(text_chunks))
        if text_chunks:
            print("First text chunk:\n", text_chunks[0][:500])  # Preview first 500 chars
        print("-" * 40)
# Out:
# --- PA 211 Disaster Community Resources.pdf ---
# Number of text chunks: 13
# First text chunk:
#  PA 211 Community Disaster and Human
# Services Resources in Pennsylvania
# Introduction
#
# Community Disaster and Human Services Resources in Pennsylvania
#
# Disasters, whether natural or man-made, have significant and far-reaching impacts on
# individuals, families, and communities. Pennsylvania, with its mix of urban, suburban, and
# rural regions, faces a diverse array of emergencies ranging from floods and severe storms to
# public health crises and housing instability. To ensure an effective res
# ----------------------------------------
#
# --- 211 RESPONDS TO URGENT NEEDS.pdf ---
# Number of text chunks: 7
# First text chunk:
#  211 RESPONDS TO URGENT NEEDS
# FACT
# 211 stood up a statewide text
# response to support employees
# impacted by the partial federal
# government shutdown who did
# not know when they would
# receive their next paycheck.
# 211 assists in times of
# disaster and widespread
# need
# FACT
# FACT
# 1
# PLEASE VOTE TO INCLUDE FUNDING FOR PENNSYLVANIA'S 211 SYSTEM IN THE STATE BUDGET TO
# SUPPORT 211'S CAPACITY TO HELP OUR COMMUNITIES IN TIMES OF DISASTER OR GREAT NEED.
# 1 2-1-1 Data
# In January 2019, 187 individuals
# subscribed to
# ----------------------------------------
#
# --- PEMA.pdf ---
# Number of text chunks: 69
# First text chunk:
#  PENNSYLVANIA
# EMERGENCY
# PREPAREDNESS
# GUIDE
# Be Informed. Be Prepared. Be Involved.
# www.Ready.PA.gov
# readypa@pa.gov
#
# Emergency Preparedness Guide. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Table of Contents
# TABLE OF CONTENTS  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Pages 2-3
# INTRODUCTION . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  Page
# ----------------------------------------
#
# --- ready-gov_disaster-preparedness-guide-for-older-adults.pdf ---
# Number of text chunks: 23
# First text chunk:
#  1
# TAKE
# CONTROL IN
# 1
# 2
# 3
# Disaster Preparedness Guide for Older Adults
#
#
#
# STEP 1 | ASSESS YOUR NEEDS
# First, know your risk. Then, understand your needs during emergencies.
# This section guides you through a self-assessment process to identify your
# specific needs so that you can create a personalized emergency plan.
# STEP 2 | MAKE A PLAN
# Develop a comprehensive emergency plan and emergency
# preparedness kit tailored to your unique needs. This section ensures
# you are well prepared to respond to
# ----------------------------------------
#
# --- Substantial Damages Toolkit.pdf ---
# Number of text chunks: 299
# First text chunk:
#
#
#
# Prepared for:
# Pennsylvania Emergency Management
# Agency
# Emergency Management, Mitigation,
# Insurance, and Resilient Communities
# (MIRC) Office
# 1310 Elmerton Avenue
# Harrisburg, Pennsylvania 17110
# Prepared by:
# PG Environmental and ERG
# 14555 Avion Parkway, Suite 125
# Chantilly, VA 20151
#
# Substantial Improvements /
# Substantial Damages Toolkit
# APRIL 2023
#
#
# ii
#
# Contents
# Introduction ................................................................................................
# ----------------------------------------

# %% [markdown]
# ## Creating Embeddings for Text Chunks
# Embeddings transform text into numerical vectors, which allow for efficient similarity search.

# %%
def create_embeddings(text, model="text-embedding-3-small"):
    """
    Creates embeddings for the given text using the specified OpenAI model.

    Args:
    text (str): The input text for which embeddings are to be created.
    model (str): The model to be used for creating embeddings. Default is "BAAI/bge-en-icl".

    Returns:
    dict: The response from the OpenAI API containing the embeddings.
    """
    # Create embeddings for the input text using the specified model
    response = client.embeddings.create(
        model=model,
        input=text
    )

    return response  # Return the response containing the embeddings

# Create embeddings for the text chunks
response = create_embeddings(text_chunks)

# %% [markdown]
# ## Implementing Context-Aware Semantic Search
# We modify retrieval to include neighboring chunks for better context.

# %%
def cosine_similarity(vec1, vec2):
    """
    Calculates the cosine similarity between two vectors.

    Args:
    vec1 (np.ndarray): The first vector.
    vec2 (np.ndarray): The second vector.

    Returns:
    float: The cosine similarity between the two vectors.
    """
    # Compute the dot product of the two vectors and divide by the product of their norms
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
def context_enriched_search(query, text_chunks, embeddings, k=1, context_size=1):
    """
    Retrieves the most relevant chunk along with its neighboring chunks.

    Args:
    query (str): Search query.
    text_chunks (List[str]): List of text chunks.
    embeddings (List[dict]): List of chunk embeddings.
    k (int): Number of relevant chunks to retrieve.
    context_size (int): Number of neighboring chunks to include.

    Returns:
    List[str]: Relevant text chunks with contextual information.
    """
    # Convert the query into an embedding vector
    query_embedding = create_embeddings(query).data[0].embedding
    similarity_scores = []

    # Compute similarity scores between query and each text chunk embedding
    for i, chunk_embedding in enumerate(embeddings):
        # Calculate cosine similarity between the query embedding and current chunk embedding
        similarity_score = cosine_similarity(np.array(query_embedding), np.array(chunk_embedding.embedding))
        # Store the index and similarity score as a tuple
        similarity_scores.append((i, similarity_score))

    # Sort chunks by similarity score in descending order (highest similarity first)
    similarity_scores.sort(key=lambda x: x[1], reverse=True)

    # Get the index of the most relevant chunk
    top_index = similarity_scores[0][0]

    # Define the range for context inclusion
    # Ensure we don't go below 0 or beyond the length of text_chunks
    start = max(0, top_index - context_size)
    end = min(len(text_chunks), top_index + context_size + 1)

    # Return the relevant chunk along with its neighboring context chunks
    return [text_chunks[i] for i in range(start, end)]

# %% [markdown]
# ## Running a Query with Context Retrieval
# We now test the context-enriched retrieval.

# %%
# Load the validation dataset from a JSON file
with open('/Users/kekunkoya/Desktop/Revised RAG Project/PA211_expanded_dataset.json') as f:
    data = json.load(f)

# Extract the first question from the dataset to use as our query
query = data[20]['question']

# Retrieve the most relevant chunk and its neighboring chunks for context
# Parameters:
# - query: The question we're searching for
# - text_chunks: Our text chunks extracted from the PDF
# - response.data: The embeddings of our text chunks
# - k=1: Return the top match
# - context_size=1: Include 1 chunk before and after the top match for context
top_chunks = context_enriched_search(query, text_chunks, response.data, k=1, context_size=1)

# Print the query for reference
print("Query:", query)
# Print each retrieved chunk with a heading and separator
for i, chunk in enumerate(top_chunks):
    print(f"Context {i + 1}:\n{chunk}\n=====================================")
# Out:
# Query: Where can individuals with oxygen tanks or power-dependent medical equipment safely recharge during outages, as mentioned in the PEMA Special Medical Needs Manual?
# Context 1:
# DI or PDA is used to make
# determinations of the type of declaration, which impacts the type and amount of assistance
# provided to communities and property owners.
# •
# FEMA provides several FEMA Disaster Assistance programs to assist governments and
# survivors respond to and recover from federally declared disasters.
# o Individual Assistance (IA): Provides federal awards to individuals, households,
# states, local governments, tribes, and territories to support individual disaster
# survivors. Joint PDAs allow impacted governments to identify and assess disaster
# damages to determine whether jurisdictions will request an IA major disaster
# declaration.
# o Public Assistance (PA): Provides federal assistance to support communities’
# recovery from major disasters by providing them with grant assistance for debris
# removal and life-saving emergency protective measures and for restoring public
#
#
#
# PEMA SI/SD Toolkit
#
#
# April 2023
# 40
#
# infrastructure. Joint PDAs are conducted to identi
# =====================================
# Context 2:
# assistance for debris
# removal and life-saving emergency protective measures and for restoring public
#
#
#
# PEMA SI/SD Toolkit
#
#
# April 2023
# 40
#
# infrastructure. Joint PDAs are conducted to identify disaster-related damage and
# determine whether jurisdictions are eligible for PA.
# o Hazard Mitigation Grant Program (HMGP): Helps communities implement hazard
# mitigation measures after a major disaster declaration in the areas of the state to
# reduce the risk of loss of life and property from future disasters.
# •
# When assessing damages, entities may use a scale similar to Figure 6 to evaluate the level of
# flood damage.
#
# Figure F-1. Summary of Flood Damage Levels.
# Flood Damage Impact Ratings
# Affected
# •
# Any waterline in the crawl space or an unfinished basement when essential
# living space or mechanical components are not damaged or submerged.
# •
# Damage to a porch, carport, garage, and/or an outbuilding, etc.
#
# Minor
# •
# Waterline at 1 to 3 inches in an essential living
# =====================================
# Context 3:
# iving space or mechanical components are not damaged or submerged.
# •
# Damage to a porch, carport, garage, and/or an outbuilding, etc.
#
# Minor
# •
# Waterline at 1 to 3 inches in an essential living space.
# •
# When waterline exceeds 3 inches but is below 18 inches, damage may be major
# or minor depending on the flowing factors: duration of the flood; contaminants
# in the water; if waterline reached outlets; and number of essential living spaces
# flooded.
# •
# Any waterline in a finished basement.
# Major
# •
# Waterline above 18 inches or the electrical outlets in an essential living space.
# •
# Waterline on the first floor (regardless of depth) of a residence when basement
# is completely full.
# •
# When waterline exceeds 3 inches but is below 18 inches, damage may be major
# or minor depending on the following factors: duration of the flood;
# contaminates in the water; if waterline reached outlets; and number of essential
# living spaces flooded.
# Destroyed
# •
# Waterline at the rooflin
# =====================================

# %% [markdown]
# ## Generating a Response Using Retrieved Context
# We now generate a response using LLM.

# %%
# Define the system prompt for the AI assistant
system_prompt = "You are an AI assistant that strictly answers based on the given context. If the answer cannot be derived directly from the provided context, respond with: 'I do not have enough information to answer that.'"

def generate_response(system_prompt, user_message, model="gpt-4o-mini"):
    """
    Generates a response from the AI model based on the system prompt and user message.

    Args:
    system_prompt (str): The system prompt to guide the Homelessness AI.
    user_message (str): The user's message or query.
    model (str): The model to be used for generating the response. Default is "gpt-4o-mini".

    Returns:
    dict: The response from the AI model.
    """
    response = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message}
        ]
    )
    return response

# Create the user prompt based on the top chunks
user_prompt = "\n".join([f"Context {i + 1}:\n{chunk}\n=====================================\n" for i, chunk in enumerate(top_chunks)])
user_prompt = f"{user_prompt}\nQuestion: {query}"

# Generate AI response
ai_response = generate_response(system_prompt, user_prompt)

# %% [markdown]
# ## Evaluating the AI Response
# We compare the AI response with the expected answer and assign a score.

# %%
# Define the system prompt for the evaluation system
evaluate_system_prompt = "You are an intelligent evaluation system tasked with assessing the AI assistant's responses. If the AI assistant's response is very close to the true response, assign a score of 1. If the response is incorrect or unsatisfactory in relation to the true response, assign a score of 0. If the response is partially aligned with the true response, assign a score of 0.5."

# Create the evaluation prompt by combining the user query, AI response, true response, and evaluation system prompt
evaluation_prompt = f"User Query: {query}\nAI Response:\n{ai_response.choices[0].message.content}\nTrue Response: {data[0]['ideal_answer']}\n{evaluate_system_prompt}"

# Generate the evaluation response using the evaluation system prompt and evaluation prompt
evaluation_response = generate_response(evaluate_system_prompt, evaluation_prompt)

# Print the evaluation response
print(evaluation_response.choices[0].message.content)
# Out:
# Score: 0

# %%
import json
import numpy as np
from openai import OpenAI

# --- Load the dataset ---
with open("PA211_expanded_dataset.json", "r") as f:
    data = json.load(f)

# --- Initialize OpenAI client ---
client = OpenAI()

# --- Cosine similarity function ---
def cosine_similarity(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# --- Embedding-based evaluation ---
def evaluate_response(user_query, ai_answer, true_answer):
    ai_emb = client.embeddings.create(
        model="text-embedding-3-small",
        input=ai_answer
    ).data[0].embedding
    
    true_emb = client.embeddings.create(
        model="text-embedding-3-small",
        input=true_answer
    ).data[0].embedding

    similarity = cosine_similarity(ai_emb, true_emb)

    if similarity > 0.90:
        score = 1
    elif similarity > 0.70:
        score = 0.5
    else:
        score = 0

    return score, similarity

# --- LLM verification ---
def llm_verify(user_query, ai_answer, true_answer):
    evaluation_prompt = f"""
You are an evaluation system. Compare the AI's answer with the true answer.

User Query: {user_query}

AI Answer:
{ai_answer}

True Answer:
{true_answer}

Output ONLY a number:
1 - Very close match
0.5 - Partial match
0 - Incorrect
"""
    llm_response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": evaluation_prompt}],
        temperature=0
    )
    return llm_response.choices[0].message.content.strip()

# --- Main evaluation loop ---
results = []

for i, item in enumerate(data):
    user_query = item['question']
    true_answer = item['ideal_answer']

    # Step 1: Generate AI answer (replace with your model)
    ai_gen = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": user_query}],
        temperature=0
    )
    ai_answer = ai_gen.choices[0].message.content

    # Step 2: Embedding-based scoring
    score, similarity = evaluate_response(user_query, ai_answer, true_answer)

    # Step 3: Optional LLM verification
    llm_score = llm_verify(user_query, ai_answer, true_answer)

    # Step 4: Store results
    results.append({
        "query": user_query,
        "ai_answer": ai_answer,
        "true_answer": true_answer,
        "embedding_score": score,
        "similarity": round(similarity, 3),
        "llm_score": llm_score
    })

# --- Save results to file ---
with open("evaluation_results.json", "w") as f:
    json.dump(results, f, indent=2)

print("✅ Evaluation complete! Results saved to evaluation_results.json")
# Out:
# ✅ Evaluation complete! Results saved to evaluation_results.json

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Print results in a readable table ---
print(f"{'Query':<50} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9}")
print("-" * 90)

for r in results:
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    print(f"{query_preview:<50} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9}")

# --- Optional: Show only incorrect answers ---
print("\n Incorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"- {r['query']}")
# Out:
# Query                                              | Embed Score  | Similarity | LLM Score
# ------------------------------------------------------------------------------------------
# What steps does the PEMA Disaster Resource Guid... | 0.5          | 0.76       | 0.5
# According to the PA 211 Emergency Resource Manu... | 0.5          | 0.771      | 0.5
# What shelter options are listed in the PEMA Eme... | 0.5          | 0.728      | 0.5
# How does the PEMA guide recommend seniors in Ha... | 0.5          | 0.715      | 0.5
# Which organizations provide water delivery or p... | 0            | 0.647      | 0.5
# What school or community-based child meal progr... | 0.5          | 0.788      | 0.5
# Where can culturally appropriate food be access... | 0.5          | 0.75       | 0.5
# What guidance does PEMA provide on water safety... | 0.5          | 0.783      | 1
# How does PA 211 assist individuals needing wate... | 0.5          | 0.801      | 0.5
# What does the Red Cross and PEMA shelter guide ... | 0.5          | 0.865      | 0.5
# Where are crisis shelters for domestic violence... | 0.5          | 0.752      | 0.5
# What are the recommended first aid or urgent ca... | 0            | 0.666      | 0.5
# According to the PA 211 Medication Emergency FA... | 0.5          | 0.701      | 0.5
# What mental health hotlines or crisis counselin... | 0.5          | 0.816      | 0.5
# Where does the PEMA Winter Emergency Guide reco... | 0.5          | 0.746      | 0.5
# How does PA 211 recommend accessing communicati... | 0.5          | 0.757      | 0.5
# What evacuation resources are described for peo... | 0.5          | 0.723      | 0.5
# According to PEMA Flood Preparedness Resource, ... | 0.5          | 0.868      | 0.5
# What steps should be taken to file a FEMA disas... | 0.5          | 0.743      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | 0.5          | 0.857      | 1
# Where can individuals with oxygen tanks or powe... | 0.5          | 0.852      | 0.5
# What instructions does the PEMA Home Damage Ass... | 0.5          | 0.837      | 0.5
# According to the PA 211 Infant and Family Emerg... | 0.5          | 0.813      | 0.5
# Where does the PEMA Community Resource Guide su... | 0.5          | 0.869      | 1
# What options are presented in the PA 211 Disast... | 0.5          | 0.869      | 0.5
# What steps does the PEMA Disaster Resource Guid... | 0.5          | 0.82       | 0.5
# According to the PA 211 Emergency Resource Manu... | 0.5          | 0.803      | 0.5
# What shelter options are listed in the PEMA Eme... | 0.5          | 0.741      | 0.5
# How does the PEMA guide recommend seniors in Ha... | 0.5          | 0.719      | 0.5
# Which organizations provide water delivery or p... | 0            | 0.649      | 0.5
# What school or community-based child meal progr... | 0.5          | 0.786      | 0.5
# Where can culturally appropriate food be access... | 0.5          | 0.747      | 0.5
# What guidance does PEMA provide on water safety... | 0.5          | 0.787      | 1
# How does PA 211 assist individuals needing wate... | 0.5          | 0.784      | 0.5
# What does the Red Cross and PEMA shelter guide ... | 0.5          | 0.863      | 0.5
# Where are crisis shelters for domestic violence... | 0.5          | 0.753      | 0.5
# What are the recommended first aid or urgent ca... | 0            | 0.668      | 0.5
# According to the PA 211 Medication Emergency FA... | 0            | 0.65       | 0.5
# What mental health hotlines or crisis counselin... | 0.5          | 0.811      | 0.5
# Where does the PEMA Winter Emergency Guide reco... | 0.5          | 0.765      | 0.5
# How does PA 211 recommend accessing communicati... | 0.5          | 0.74       | 0.5
# What evacuation resources are described for peo... | 0.5          | 0.701      | 0.5
# According to PEMA Flood Preparedness Resource, ... | 0.5          | 0.868      | 0.5
# What steps should be taken to file a FEMA disas... | 0.5          | 0.741      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | 0.5          | 0.857      | 1
# Where can individuals with oxygen tanks or powe... | 0.5          | 0.844      | 0.5
# What instructions does the PEMA Home Damage Ass... | 0.5          | 0.831      | 0.5
# According to the PA 211 Infant and Family Emerg... | 0.5          | 0.819      | 0.5
# Where does the PEMA Community Resource Guide su... | 0.5          | 0.869      | 1
# What options are presented in the PA 211 Disast... | 0.5          | 0.868      | 0.5
# Can I volunteer to help others in a disaster?      | 0            | 0.524      | 0.5
# How can older adults assess their personal need... | 0.5          | 0.713      | 1
# What steps should I take to create a family eme... | 0            | 0.684      | 1
# If I have a disability, how can I ensure my eme... | 0.5          | 0.704      | 1
# How can I stay informed during a disaster if I ... | 0            | 0.646      | 1
# What should I do if I am unable to evacuate dur... | 0            | 0.661      | 1
# What items should older adults include in an em... | 0            | 0.691      | 1
# How can older adults engage their support netwo... | 0            | 0.566      | 1
# What special steps should older adults in rural... | 0            | 0.641      | 1
# Where can I get help building an emergency plan... | 0.5          | 0.733      | 1
# How can I include my pet or service animal in m... | 0.5          | 0.729      | 1
# How can older adults assess their personal need... | 0.5          | 0.722      | 1
# What steps should I take to create a family eme... | 0            | 0.69       | 1
# If I have a disability, how can I ensure my eme... | 0.5          | 0.701      | 1
# How can I stay informed during a disaster if I ... | 0            | 0.648      | 1
# What should I do if I am unable to evacuate dur... | 0            | 0.644      | 1
# What items should older adults include in an em... | 0            | 0.684      | 1
# How can older adults engage their support netwo... | 0            | 0.589      | 1
# What special steps should older adults in rural... | 0            | 0.637      | 1
# Where can I get help building an emergency plan... | 0.5          | 0.72       | 1
# How can I include my pet or service animal in m... | 0.5          | 0.737      | 1
#
#  Incorrect answers (Embed Score = 0):
# - Which organizations provide water delivery or pickup for vulnerable residents, as referenced in the PA 211 Resource Directory for ZIP 17104?
# - What are the recommended first aid or urgent care alternatives when local hospitals are over capacity, per the PEMA Emergency Medical Resources PDF?
# - Which organizations provide water delivery or pickup for vulnerable residents, as referenced in the PA 211 Resource Directory for ZIP 17104?
# - What are the recommended first aid or urgent care alternatives when local hospitals are over capacity, per the PEMA Emergency Medical Resources PDF?
# - According to the PA 211 Medication Emergency FAQ, how can individuals get emergency insulin or prescription refills during a disaster?
# - Can I volunteer to help others in a disaster?
# - What steps should I take to create a family emergency communication plan?
# - How can I stay informed during a disaster if I don't have a smartphone?
# - What should I do if I am unable to evacuate during an emergency?
# - What items should older adults include in an emergency preparedness kit?
# - How can older adults engage their support network for disaster preparedness?
# - What special steps should older adults in rural areas take to prepare for disasters?
# - What steps should I take to create a family emergency communication plan?
# - How can I stay informed during a disaster if I don't have a smartphone?
# - What should I do if I am unable to evacuate during an emergency?
# - What items should older adults include in an emergency preparedness kit?
# - How can older adults engage their support network for disaster preparedness?
# - What special steps should older adults in rural areas take to prepare for disasters?

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Print results in a readable table ---
print(f"{'Query':<50} | {'AI Response':<60} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9}")
print("-" * 150)

for r in results:
    # Truncate long query and AI response for display
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    ai_preview = (r['ai_answer'][:57] + "...") if len(r['ai_answer']) > 60 else r['ai_answer']

    print(f"{query_preview:<50} | {ai_preview:<60} | {r['embedding_score']:<12} | {r['similarity']:<10} | {r['llm_score']:<9}")

# --- Optional: Show only incorrect answers with details ---
print("\n  Incorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"\nQ: {r['query']}")
        print(f"AI: {r['ai_answer']}")
        print(f"TRUE: {r['true_answer']}")
# Out:
# Query                                              | AI Response                                                  | Embed Score  | Similarity | LLM Score
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# What steps does the PEMA Disaster Resource Guid... | The PEMA Disaster Resource Guide typically recommends the... | 0.5          | 0.76       | 0.5
# According to the PA 211 Emergency Resource Manu... | Residents of ZIP code 17104 can access ice and mobile pho... | 0.5          | 0.771      | 0.5
# What shelter options are listed in the PEMA Eme... | I don't have access to real-time databases or specific di... | 0.5          | 0.728      | 0.5
# How does the PEMA guide recommend seniors in Ha... | The PEMA (Pennsylvania Emergency Management Agency) guide... | 0.5          | 0.715      | 0.5
# Which organizations provide water delivery or p... | To find specific organizations that provide water deliver... | 0            | 0.647      | 0.5
# What school or community-based child meal progr... | I don't have access to real-time data or specific documen... | 0.5          | 0.788      | 0.5
# Where can culturally appropriate food be access... | To find culturally appropriate food after a disaster in H... | 0.5          | 0.75       | 0.5
# What guidance does PEMA provide on water safety... | The Pennsylvania Emergency Management Agency (PEMA) provi... | 0.5          | 0.783      | 1
# How does PA 211 assist individuals needing wate... | PA 211 provides critical assistance to individuals who re... | 0.5          | 0.801      | 0.5
# What does the Red Cross and PEMA shelter guide ... | The Red Cross and PEMA (Pennsylvania Emergency Management... | 0.5          | 0.865      | 0.5
# Where are crisis shelters for domestic violence... | To find crisis shelters for domestic violence survivors d... | 0.5          | 0.752      | 0.5
# What are the recommended first aid or urgent ca... | I don't have access to specific documents, including the ... | 0            | 0.666      | 0.5
# According to the PA 211 Medication Emergency FA... | During a disaster, individuals can obtain emergency insul... | 0.5          | 0.701      | 0.5
# What mental health hotlines or crisis counselin... | In the Disaster Behavioral Health section of the PA 211 E... | 0.5          | 0.816      | 0.5
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide recommends that residents... | 0.5          | 0.746      | 0.5
# How does PA 211 recommend accessing communicati... | PA 211 recommends several strategies for accessing commun... | 0.5          | 0.757      | 0.5
# What evacuation resources are described for peo... | I don't have access to specific documents, including the ... | 0.5          | 0.723      | 0.5
# According to PEMA Flood Preparedness Resource, ... | Residents in Harrisburg can pick up free sandbags or floo... | 0.5          | 0.868      | 0.5
# What steps should be taken to file a FEMA disas... | Filing a FEMA disaster claim involves several steps, as o... | 0.5          | 0.743      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | Yes, the PA 211 Disaster Support Guide indicates that und... | 0.5          | 0.857      | 1
# Where can individuals with oxygen tanks or powe... | Individuals with oxygen tanks or power-dependent medical ... | 0.5          | 0.852      | 0.5
# What instructions does the PEMA Home Damage Ass... | The PEMA Home Damage Assessment Guide provides specific i... | 0.5          | 0.837      | 0.5
# According to the PA 211 Infant and Family Emerg... | In Harrisburg, families can get diapers and baby formula ... | 0.5          | 0.813      | 0.5
# Where does the PEMA Community Resource Guide su... | The PEMA Community Resource Guide suggests that individua... | 0.5          | 0.869      | 1
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ typically provides vario... | 0.5          | 0.869      | 0.5
# What steps does the PEMA Disaster Resource Guid... | The PEMA Disaster Resource Guide typically recommends the... | 0.5          | 0.82       | 0.5
# According to the PA 211 Emergency Resource Manu... | Residents of ZIP code 17104 can access ice and mobile pho... | 0.5          | 0.803      | 0.5
# What shelter options are listed in the PEMA Eme... | I don't have access to real-time databases or specific di... | 0.5          | 0.741      | 0.5
# How does the PEMA guide recommend seniors in Ha... | The PEMA (Pennsylvania Emergency Management Agency) guide... | 0.5          | 0.719      | 0.5
# Which organizations provide water delivery or p... | To find specific organizations that provide water deliver... | 0            | 0.649      | 0.5
# What school or community-based child meal progr... | I don't have access to real-time data or specific documen... | 0.5          | 0.786      | 0.5
# Where can culturally appropriate food be access... | To find culturally appropriate food after a disaster in H... | 0.5          | 0.747      | 0.5
# What guidance does PEMA provide on water safety... | The Pennsylvania Emergency Management Agency (PEMA) provi... | 0.5          | 0.787      | 1
# How does PA 211 assist individuals needing wate... | PA 211 provides critical assistance to individuals who re... | 0.5          | 0.784      | 0.5
# What does the Red Cross and PEMA shelter guide ... | The Red Cross and PEMA (Pennsylvania Emergency Management... | 0.5          | 0.863      | 0.5
# Where are crisis shelters for domestic violence... | To find crisis shelters for domestic violence survivors d... | 0.5          | 0.753      | 0.5
# What are the recommended first aid or urgent ca... | I don't have access to specific documents, including the ... | 0            | 0.668      | 0.5
# According to the PA 211 Medication Emergency FA... | During a disaster, individuals can obtain emergency insul... | 0            | 0.65       | 0.5
# What mental health hotlines or crisis counselin... | In the Disaster Behavioral Health section of the PA 211 E... | 0.5          | 0.811      | 0.5
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide recommends that residents... | 0.5          | 0.765      | 0.5
# How does PA 211 recommend accessing communicati... | PA 211 recommends several strategies for accessing commun... | 0.5          | 0.74       | 0.5
# What evacuation resources are described for peo... | I'm sorry, but I can't access external documents or speci... | 0.5          | 0.701      | 0.5
# According to PEMA Flood Preparedness Resource, ... | Residents in Harrisburg can pick up free sandbags or floo... | 0.5          | 0.868      | 0.5
# What steps should be taken to file a FEMA disas... | Filing a FEMA disaster claim involves several steps, as o... | 0.5          | 0.741      | 0.5
# Does the PA 211 Disaster Support Guide indicate... | Yes, the PA 211 Disaster Support Guide indicates that und... | 0.5          | 0.857      | 1
# Where can individuals with oxygen tanks or powe... | Individuals with oxygen tanks or power-dependent medical ... | 0.5          | 0.844      | 0.5
# What instructions does the PEMA Home Damage Ass... | The PEMA Home Damage Assessment Guide provides specific i... | 0.5          | 0.831      | 0.5
# According to the PA 211 Infant and Family Emerg... | In Harrisburg, families can obtain diapers and baby formu... | 0.5          | 0.819      | 0.5
# Where does the PEMA Community Resource Guide su... | The PEMA Community Resource Guide suggests that individua... | 0.5          | 0.869      | 1
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ typically provides vario... | 0.5          | 0.868      | 0.5
# Can I volunteer to help others in a disaster?      | Yes, you can definitely volunteer to help others in a dis... | 0            | 0.524      | 0.5
# How can older adults assess their personal need... | Assessing personal needs before a disaster is crucial for... | 0.5          | 0.713      | 1
# What steps should I take to create a family eme... | Creating a family emergency communication plan is essenti... | 0            | 0.684      | 1
# If I have a disability, how can I ensure my eme... | Ensuring that your emergency kit is accessible if you hav... | 0.5          | 0.704      | 1
# How can I stay informed during a disaster if I ... | Staying informed during a disaster without a smartphone c... | 0            | 0.646      | 1
# What should I do if I am unable to evacuate dur... | If you find yourself unable to evacuate during an emergen... | 0            | 0.661      | 1
# What items should older adults include in an em... | Creating an emergency preparedness kit for older adults i... | 0            | 0.691      | 1
# How can older adults engage their support netwo... | Engaging a support network for disaster preparedness is c... | 0            | 0.566      | 1
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0            | 0.641      | 1
# Where can I get help building an emergency plan... | If you have limited resources and need help building an e... | 0.5          | 0.733      | 1
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.729      | 1
# How can older adults assess their personal need... | Assessing personal needs before a disaster is crucial for... | 0.5          | 0.722      | 1
# What steps should I take to create a family eme... | Creating a family emergency communication plan is essenti... | 0            | 0.69       | 1
# If I have a disability, how can I ensure my eme... | Ensuring that your emergency kit is accessible if you hav... | 0.5          | 0.701      | 1
# How can I stay informed during a disaster if I ... | Staying informed during a disaster without a smartphone c... | 0            | 0.648      | 1
# What should I do if I am unable to evacuate dur... | If you find yourself unable to evacuate during an emergen... | 0            | 0.644      | 1
# What items should older adults include in an em... | Creating an emergency preparedness kit for older adults i... | 0            | 0.684      | 1
# How can older adults engage their support netwo... | Engaging a support network for disaster preparedness is c... | 0            | 0.589      | 1
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0            | 0.637      | 1
# Where can I get help building an emergency plan... | If you have limited resources and need help building an e... | 0.5          | 0.72       | 1
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.737      | 1
#
#   Incorrect answers (Embed Score = 0):
#
# Q: Which organizations provide water delivery or pickup for vulnerable residents, as referenced in the PA 211 Resource Directory for ZIP 17104?
# AI: To find specific organizations that provide water delivery or pickup for vulnerable residents in the ZIP code 17104, you would typically refer to the PA 211 Resource Directory directly. PA 211 is a resource that connects individuals with local services, including those for water delivery and other essential needs.
#
# You can visit the PA 211 website or call their helpline to get the most accurate and up-to-date information on organizations in your area that offer these services. They can provide details on local nonprofits, community organizations, or government programs that assist vulnerable residents with water access.
# TRUE: The PA 211 Resource Directory identifies the Farm Show Complex as an emergency bottled water distribution site and lists United Way and VOAD as coordinators for home delivery to seniors and people with disabilities.
#
# Q: What are the recommended first aid or urgent care alternatives when local hospitals are over capacity, per the PEMA Emergency Medical Resources PDF?
# AI: I don't have access to specific documents, including the PEMA Emergency Medical Resources PDF. However, I can provide general recommendations for first aid and urgent care alternatives when local hospitals are over capacity:
#
# 1. **Urgent Care Clinics**: These facilities can handle non-life-threatening conditions and are often less crowded than emergency rooms.
#
# 2. **Telemedicine Services**: Many healthcare providers offer virtual consultations, which can be a quick way to get medical advice without visiting a facility.
#
# 3. **Community Health Centers**: These centers often provide a range of services and may have shorter wait times.
#
# 4. **Pharmacies with Health Clinics**: Some pharmacies have walk-in clinics that can treat minor ailments and provide basic health services.
#
# 5. **Home Care**: For minor injuries or illnesses, consider home care options, including over-the-counter medications and first aid supplies.
#
# 6. **Local Health Departments**: They may offer resources or guidance on where to seek care when hospitals are overwhelmed.
#
# 7. **First Aid Kits**: Having a well-stocked first aid kit at home can help manage minor injuries effectively.
#
# 8. **Emergency Services**: If a situation is life-threatening, always call emergency services, as they can provide immediate assistance.
#
# For the most accurate and specific information, please refer to the PEMA Emergency Medical Resources PDF or your local health department's guidelines.
# TRUE: The PEMA Emergency Medical Resources PDF recommends seeking mobile medical units or urgent care pop-ups coordinated by UPMC or Penn State Health, which are activated when hospitals are at capacity. Locations rotate and are announced through 211 and local emergency alerts.
#
# Q: Which organizations provide water delivery or pickup for vulnerable residents, as referenced in the PA 211 Resource Directory for ZIP 17104?
# AI: To find specific organizations that provide water delivery or pickup for vulnerable residents in the ZIP code 17104, you would typically refer to the PA 211 Resource Directory directly. PA 211 is a resource that connects individuals with local services, including those for water delivery and other essential needs.
#
# You can visit the PA 211 website or call their helpline to get the most accurate and up-to-date information on organizations in your area that offer these services. They can provide details on local nonprofits, government programs, and community resources that assist vulnerable residents with water access.
# TRUE: The PA 211 Resource Directory identifies the Farm Show Complex as an emergency bottled water distribution site and lists United Way and VOAD as coordinators for home delivery to seniors and people with disabilities.
#
# Q: What are the recommended first aid or urgent care alternatives when local hospitals are over capacity, per the PEMA Emergency Medical Resources PDF?
# AI: I don't have access to specific documents, including the PEMA Emergency Medical Resources PDF. However, I can provide general recommendations for first aid or urgent care alternatives when local hospitals are over capacity:
#
# 1. **Urgent Care Clinics**: These facilities can handle non-life-threatening conditions and are often less crowded than emergency rooms.
#
# 2. **Telemedicine Services**: Many healthcare providers offer virtual consultations, which can be a quick way to get medical advice without visiting a facility.
#
# 3. **Walk-in Clinics**: Pharmacies and retail stores often have walk-in clinics that can treat minor injuries and illnesses.
#
# 4. **Community Health Centers**: These centers provide a range of health services and may have shorter wait times.
#
# 5. **First Aid Kits**: For minor injuries, having a well-stocked first aid kit can help manage situations at home.
#
# 6. **Local Health Departments**: They may offer resources or guidance on where to seek care when hospitals are overwhelmed.
#
# 7. **Home Care**: For minor ailments, self-care measures and over-the-counter medications can be effective.
#
# 8. **Emergency Medical Services (EMS)**: If a situation is life-threatening, always call 911 or your local emergency number, as EMS can provide immediate care and transport.
#
# For the most accurate and specific information, please refer to the PEMA Emergency Medical Resources PDF or your local health department's guidelines.
# TRUE: The PEMA Emergency Medical Resources PDF recommends seeking mobile medical units or urgent care pop-ups coordinated by UPMC or Penn State Health, which are activated when hospitals are at capacity. Locations rotate and are announced through 211 and local emergency alerts.
#
# Q: According to the PA 211 Medication Emergency FAQ, how can individuals get emergency insulin or prescription refills during a disaster?
# AI: During a disaster, individuals can obtain emergency insulin or prescription refills by following these steps:
#
# 1. **Contact Your Pharmacy**: Reach out to your local pharmacy to inquire about their policies for emergency refills. Many pharmacies have protocols in place for providing medications during emergencies.
#
# 2. **State Emergency Services**: Check with state or local emergency services, as they may have resources or programs to assist individuals in obtaining necessary medications during a disaster.
#
# 3. **Healthcare Providers**: Contact your healthcare provider or doctor’s office. They may be able to provide a prescription refill or direct you to resources for obtaining your medication.
#
# 4. **Emergency Shelters**: If you are in an emergency shelter, staff may be able to assist you in accessing your medications.
#
# 5. **Insurance Provider**: Reach out to your health insurance provider to understand your coverage for emergency medication refills.
#
# 6. **Local Health Departments**: Some local health departments may have programs to help individuals access medications during emergencies.
#
# It's important to plan ahead and have a strategy in place for accessing medications during potential disasters.
# TRUE: The PA 211 Medication Emergency FAQ states that residents can contact 211 to be referred to local clinics like Hamilton Health Center, which are authorized for prescription replacement. Emergency pharmacy partners can provide insulin refills with proof of need.
#
# Q: Can I volunteer to help others in a disaster?
# AI: Yes, you can definitely volunteer to help others in a disaster. Many organizations and agencies seek volunteers to assist in disaster response and recovery efforts. Here are some steps you can take to get involved:
#
# 1. **Research Local Organizations**: Look for local non-profits, community organizations, or national agencies like the American Red Cross, Team Rubicon, or local emergency management offices that coordinate disaster response efforts.
#
# 2. **Get Trained**: Some organizations offer training programs for volunteers. This training can prepare you for various roles, such as providing first aid, managing supplies, or helping with logistics.
#
# 3. **Register as a Volunteer**: Many organizations have a volunteer registration process. Sign up to be on their list of volunteers so they can contact you when help is needed.
#
# 4. **Stay Informed**: Follow local news and social media channels to stay updated on disasters in your area and the needs of affected communities.
#
# 5. **Be Prepared**: If you plan to volunteer during a disaster, ensure you have the necessary supplies, such as food, water, and personal safety gear, and be ready to respond quickly.
#
# 6. **Consider Your Skills**: Think about what skills you can offer. Medical professionals, counselors, logistics experts, and those with experience in construction or food service can be particularly valuable.
#
# 7. **Be Flexible**: Disaster response can be unpredictable, so be prepared to adapt to changing needs and situations.
#
# 8. **Support Recovery Efforts**: Volunteering doesn’t just happen during the immediate response phase. Many organizations also need help with long-term recovery efforts, which can last for months or even years.
#
# Remember to prioritize your safety and well-being while volunteering, and follow the guidance of local authorities and organizations.
# TRUE: Yes! Call 2-1-1 or visit the PA VOAD website to sign up for: Debris removal crews, shelter assistance, and food and supply packaging. Training and background checks may be required.
#
# Q: What steps should I take to create a family emergency communication plan?
# AI: Creating a family emergency communication plan is essential for ensuring that all family members know how to stay in touch and where to meet in case of an emergency. Here are the steps you can take to create an effective plan:
#
# ### 1. **Assess Your Risks**
#    - Identify potential emergencies that could affect your family, such as natural disasters (earthquakes, floods, hurricanes), fires, or other crises.
#    - Consider your location and any specific risks associated with it.
#
# ### 2. **Establish Communication Methods**
#    - **Primary Contact:** Designate a primary contact person outside your immediate area (a relative or friend) who can help relay information.
#    - **Communication Tools:** Decide on the methods of communication (text, phone calls, social media, messaging apps) and ensure everyone knows how to use them.
#    - **Emergency Apps:** Consider using emergency apps that can help with communication and information sharing.
#
# ### 3. **Create a Family Contact List**
#    - Compile a list of important contacts, including family members, friends, neighbors, and emergency services.
#    - Include phone numbers, email addresses, and physical addresses.
#
# ### 4. **Establish Meeting Points**
#    - Identify safe locations where family members can meet after an emergency, both near your home and further away in case of evacuation.
#    - Make sure everyone knows how to get to these locations.
#
# ### 5. **Develop a Communication Plan**
#    - Outline how family members will communicate during an emergency. For example, if phone lines are down, you might rely on text messages or social media.
#    - Discuss how to check in with each other and how often to do so.
#
# ### 6. **Practice the Plan**
#    - Conduct regular drills to practice your communication plan and ensure everyone knows their roles and responsibilities.
#    - Review the plan periodically and update it as necessary.
#
# ### 7. **Prepare an Emergency Kit**
#    - Assemble an emergency kit that includes essential items such as water, food, first aid supplies, flashlights, batteries, and important documents.
#    - Ensure that everyone knows where the kit is stored.
#
# ### 8. **Educate Family Members**
#    - Teach family members about the plan, including how to use communication tools and what to do in various emergency scenarios.
#    - Discuss the importance of staying calm and following the plan during an emergency.
#
# ### 9. **Stay Informed**
#    - Keep up to date with local emergency services and alerts. Sign up for local emergency notifications if available.
#    - Review and update your plan regularly, especially after any changes in family circumstances or after an emergency.
#
# ### 10. **Document the Plan**
#    - Write down the communication plan and distribute copies to all family members.
#    - Consider keeping a digital copy accessible on a shared platform or cloud service.
#
# By following these steps, you can create a comprehensive family emergency communication plan that helps ensure everyone stays connected and safe during a crisis.
# TRUE: Start by talking with your family and support network about how you will contact each other and where to meet if separated. Keep a list of emergency contacts in your wallet and post important numbers near your phone. Use the Make a Plan Form from Ready.gov.
#
# Q: How can I stay informed during a disaster if I don't have a smartphone?
# AI: Staying informed during a disaster without a smartphone can be challenging, but there are several effective methods you can use:
#
# 1. **Battery-Powered or Hand-Crank Radio**: Invest in a battery-powered or hand-crank emergency radio. These radios can receive NOAA Weather Radio broadcasts, which provide real-time updates on weather conditions and emergency alerts.
#
# 2. **Local News Radio Stations**: Tune in to local AM or FM radio stations that provide news updates. Many stations will cover emergency situations and provide information on evacuations, shelters, and safety tips.
#
# 3. **Television**: If you have access to a television, local news channels often provide continuous coverage during disasters. Keep a battery-operated TV or a portable one if you anticipate power outages.
#
# 4. **Community Alert Systems**: Sign up for local community alert systems that may send notifications via landline phones or through other means. Check with your local government or emergency management office for available services.
#
# 5. **Landline Phones**: Keep a landline phone available, as it may still work during power outages when mobile networks may be down. Use it to call friends, family, or local authorities for updates.
#
# 6. **Neighborhood Watch or Community Groups**: Stay connected with neighbors or local community groups. They can share information and updates about the situation in your area.
#
# 7. **Public Bulletin Boards**: Check community centers, libraries, or other public places for bulletin boards that may have posted updates and information about the disaster.
#
# 8. **Emergency Services**: Keep the contact numbers for local emergency services handy. You can call them for information or assistance.
#
# 9. **Local Government Websites**: If you have access to a computer, check your local government’s website for updates. Many municipalities provide information on their websites during emergencies.
#
# 10. **Preparedness Kits**: Prepare an emergency kit that includes essential supplies, a flashlight, batteries, and a first aid kit. This will help you stay safe and informed during a disaster.
#
# By utilizing these methods, you can stay informed and connected during a disaster even without a smartphone.
# TRUE: Listen to local radio or television for emergency broadcasts. Consider purchasing a weather radio. Join local community groups or CERTs to receive alerts.
#
# Q: What should I do if I am unable to evacuate during an emergency?
# AI: If you find yourself unable to evacuate during an emergency, here are some steps you can take to ensure your safety:
#
# 1. **Stay Informed**: Keep updated on the situation through reliable sources such as local news, emergency services, or weather alerts. Use a battery-powered radio if power is out.
#
# 2. **Find a Safe Location**: Identify a safe area in your home or building. This could be a room with no windows or a designated safe space. If you are in a multi-story building, consider moving to a higher floor if flooding is a concern.
#
# 3. **Prepare Your Space**:
#    - Close and secure windows and doors to prevent outside hazards from entering.
#    - Use towels or blankets to seal gaps under doors to keep out smoke or water.
#    - If applicable, turn off utilities (gas, water, electricity) to prevent further hazards.
#
# 4. **Gather Supplies**: Collect essential items such as:
#    - Water and non-perishable food
#    - First aid kit
#    - Flashlights and batteries
#    - Medications
#    - Important documents (ID, insurance, etc.)
#    - A whistle to signal for help
#
# 5. **Communicate**: If possible, inform family or friends of your situation. Use text messages or social media if phone lines are congested.
#
# 6. **Stay Calm**: Keep a clear head and try to remain calm. This will help you think more clearly and make better decisions.
#
# 7. **Signal for Help**: If you are in a situation where you cannot evacuate, make noise or use a signal (like a flashlight or a brightly colored cloth) to attract attention.
#
# 8. **Follow Emergency Protocols**: If you have a plan in place for emergencies, follow it. This may include specific actions based on the type of emergency (e.g., sheltering in place during a tornado).
#
# 9. **Stay Low**: If there is smoke, stay low to the ground to avoid inhalation. Cover your mouth with a cloth if necessary.
#
# 10. **Be Prepared to Move**: If conditions worsen, be ready to move to a different location within your home or building if it becomes unsafe.
#
# 11. **Wait for Help**: If you have signaled for help, stay in your safe location and wait for emergency responders to arrive.
#
# Remember, your safety is the priority. Always assess your situation and make decisions based on the immediate risks you face.
# TRUE: Shelter in place in the safest room in your home, and inform your support network of your situation. Keep a radio or phone handy for updates from officials.
#
# Q: What items should older adults include in an emergency preparedness kit?
# AI: Creating an emergency preparedness kit for older adults is essential to ensure their safety and well-being during emergencies. Here are some key items to include:
#
# 1. **Water and Food:**
#    - At least a three-day supply of water (one gallon per person per day).
#    - Non-perishable food items (canned goods, granola bars, dried fruits, etc.) that are easy to open and consume.
#
# 2. **Medications:**
#    - A supply of prescription medications (at least a week's worth).
#    - Over-the-counter medications (pain relievers, antacids, etc.).
#    - A list of all medications, dosages, and any allergies.
#
# 3. **Medical Supplies:**
#    - First aid kit (band-aids, antiseptic wipes, gauze, etc.).
#    - Any necessary medical equipment (e.g., cane, walker, hearing aids, glasses).
#    - Extra batteries for hearing aids or other devices.
#
# 4. **Personal Care Items:**
#    - Hygiene products (toothbrush, toothpaste, soap, hand sanitizer, etc.).
#    - Incontinence supplies if needed.
#
# 5. **Communication Tools:**
#    - A fully charged cell phone with a portable charger.
#    - A list of emergency contacts, including family members and caregivers.
#    - A whistle to signal for help.
#
# 6. **Important Documents:**
#    - Copies of identification (driver’s license, Medicare card).
#    - Emergency contact information.
#    - Medical records and insurance information.
#
# 7. **Comfort Items:**
#    - A blanket or sleeping bag.
#    - A flashlight with extra batteries.
#    - A radio (battery-operated or hand-crank) for news updates.
#
# 8. **Cash:**
#    - Small denominations of cash, as ATMs may not be accessible during emergencies.
#
# 9. **Transportation:**
#    - A list of accessible transportation options in case evacuation is necessary.
#
# 10. **Special Needs Items:**
#     - Items specific to individual needs (e.g., oxygen tanks, special dietary foods).
#
# 11. **Emergency Plan:**
#     - A written emergency plan that includes evacuation routes, meeting places, and how to communicate with family members.
#
# 12. **Pet Supplies:**
#     - If applicable, include food, water, and supplies for pets.
#
# It's important to regularly check and update the kit, ensuring that food and medications are not expired and that all items are in good condition. Additionally, older adults should be familiar with the contents of their emergency kit and have a plan in place for how to use it.
# TRUE: Pack water, non-perishable food, medications, extra batteries, flashlight, important documents (insurance, IDs), pet supplies, a first aid kit, and a written list of your medications and contacts.
#
# Q: How can older adults engage their support network for disaster preparedness?
# AI: Engaging a support network for disaster preparedness is crucial for older adults, as they may face unique challenges during emergencies. Here are several strategies to help them effectively involve their support network:
#
# 1. **Identify Support Network**: Encourage older adults to identify family members, friends, neighbors, and community organizations that can provide assistance during a disaster.
#
# 2. **Communication Plan**: Help them establish a clear communication plan. This includes sharing contact information, preferred methods of communication, and any specific needs or concerns they may have.
#
# 3. **Education and Training**: Organize workshops or informational sessions with their support network to educate everyone about disaster preparedness. This can include training on first aid, emergency response, and how to use emergency supplies.
#
# 4. **Create a Disaster Plan**: Work together to develop a personalized disaster preparedness plan. This should include evacuation routes, emergency contacts, medical needs, and a list of essential supplies.
#
# 5. **Regular Check-Ins**: Encourage regular check-ins with their support network to discuss preparedness plans and make updates as necessary. This can help ensure everyone is on the same page and ready to act.
#
# 6. **Practice Drills**: Conduct practice drills with their support network to ensure everyone knows their roles and responsibilities during a disaster. This can help reduce anxiety and improve response times.
#
# 7. **Resource Sharing**: Share resources such as emergency kits, information on local shelters, and community services that can assist during a disaster. This can help older adults feel more secure knowing they have access to necessary resources.
#
# 8. **Utilize Technology**: Encourage the use of technology for communication and information sharing. This can include group messaging apps, social media, or emergency alert systems to keep everyone informed.
#
# 9. **Involve Local Organizations**: Connect with local organizations that focus on disaster preparedness for older adults. These organizations can provide additional resources, training, and support.
#
# 10. **Encourage Community Engagement**: Promote participation in community preparedness events or volunteer opportunities. This can help older adults feel more connected and supported within their community.
#
# 11. **Address Mobility and Accessibility**: Discuss any mobility or accessibility issues with their support network to ensure that plans accommodate their specific needs during a disaster.
#
# 12. **Emotional Support**: Recognize the emotional aspect of disaster preparedness. Encourage open discussions about fears and concerns, and ensure that their support network is aware of how to provide emotional support during stressful times.
#
# By actively engaging their support network, older adults can enhance their disaster preparedness and ensure they have the necessary assistance and resources during emergencies.
# TRUE: Share your emergency plan with family, friends, neighbors, and caregivers. Make sure someone has a spare key and knows how to help with your medical equipment. Practice your plan together regularly.
#
# Q: What special steps should older adults in rural areas take to prepare for disasters?
# AI: Older adults in rural areas face unique challenges when preparing for disasters due to factors like limited access to resources, healthcare, and transportation. Here are some special steps they can take to prepare:
#
# 1. **Create a Personal Emergency Plan**:
#    - Develop a comprehensive emergency plan that includes communication strategies, evacuation routes, and designated meeting places.
#    - Ensure that the plan is easy to understand and accessible.
#
# 2. **Build a Support Network**:
#    - Connect with neighbors, family, and friends to establish a support system. Regularly check in with each other, especially during emergencies.
#    - Consider joining local community groups or organizations focused on disaster preparedness.
#
# 3. **Stay Informed**:
#    - Sign up for local alerts and warnings through community emergency management systems.
#    - Keep a battery-operated or hand-crank radio to receive updates during power outages.
#
# 4. **Prepare an Emergency Kit**:
#    - Assemble a disaster supply kit that includes essential items such as medications, first aid supplies, water, non-perishable food, flashlight, batteries, and personal identification.
#    - Include items specific to individual needs, such as mobility aids or hearing devices.
#
# 5. **Plan for Transportation**:
#    - Identify reliable transportation options for evacuating if necessary. This may include arranging rides with neighbors or local services.
#    - Keep a list of local transportation services and their contact information.
#
# 6. **Consider Health Needs**:
#    - Maintain an updated list of medications, medical conditions, and healthcare providers. Share this information with trusted individuals.
#    - Ensure access to necessary medical equipment and supplies.
#
# 7. **Home Safety Modifications**:
#    - Make home modifications to enhance safety, such as securing heavy furniture, installing smoke detectors, and ensuring clear exit routes.
#    - Consider using technology, such as medical alert systems, for emergencies.
#
# 8. **Practice the Plan**:
#    - Regularly review and practice the emergency plan with family and friends to ensure everyone knows their roles and responsibilities.
#    - Conduct drills to familiarize everyone with evacuation routes and procedures.
#
# 9. **Stay Connected**:
#    - Use technology to stay connected with family and friends, especially during emergencies. Consider using social media or messaging apps for updates.
#    - Encourage family members to check in regularly, especially during severe weather or disaster warnings.
#
# 10. **Know Local Resources**:
#     - Familiarize yourself with local emergency services, shelters, and resources available in your community.
#     - Reach out to local agencies or organizations that provide assistance to older adults during disasters.
#
# 11. **Mental Health Preparedness**:
#     - Prepare for the emotional impact of disasters by having coping strategies in place. This may include mindfulness practices, access to counseling, or support groups.
#
# 12. **Review and Update Plans Regularly**:
#     - Regularly review and update emergency plans and kits to ensure they remain relevant and effective as circumstances change.
#
# By taking these steps, older adults in rural areas can enhance their preparedness for disasters and improve their resilience in the face of emergencies.
# TRUE: Stock up on supplies, arrange transportation options in advance, create a backup communications plan for power/internet outages, and build a network of neighbors who can help during emergencies.
#
# Q: What steps should I take to create a family emergency communication plan?
# AI: Creating a family emergency communication plan is essential for ensuring that all family members know how to stay in touch and where to meet during an emergency. Here are the steps you can take to create an effective plan:
#
# ### 1. **Identify Emergency Scenarios**
#    - Consider the types of emergencies that could affect your family, such as natural disasters (earthquakes, floods, hurricanes), fires, medical emergencies, or other crises.
#
# ### 2. **Establish Communication Methods**
#    - **Primary Contact:** Designate a primary contact person outside the immediate area (like a relative or friend) who can help relay information.
#    - **Communication Tools:** Decide on the methods of communication (e.g., phone calls, text messages, social media, or messaging apps). Text messages may be more reliable than calls during emergencies.
#
# ### 3. **Create a Family Contact List**
#    - Compile a list of important phone numbers, including:
#      - Family members’ cell phones
#      - Work numbers
#      - School contacts
#      - Neighbors or nearby friends
#      - Emergency services (police, fire, medical)
#    - Ensure that everyone has a copy of this list, both in physical form and digitally.
#
# ### 4. **Designate Meeting Places**
#    - **Immediate Meeting Place:** Choose a safe location close to home where family members can gather if it’s safe to do so.
#    - **Alternative Meeting Place:** Select a secondary location further away in case the immediate area is unsafe or inaccessible.
#
# ### 5. **Establish Roles and Responsibilities**
#    - Assign specific roles to family members, such as who will grab emergency supplies, who will check on pets, or who will contact the primary contact person.
#
# ### 6. **Practice the Plan**
#    - Conduct regular drills to ensure everyone knows the plan and can execute it effectively. This helps to familiarize everyone with the steps to take during an emergency.
#
# ### 7. **Update the Plan Regularly**
#    - Review and update the communication plan at least once a year or whenever there are significant changes in your family (e.g., new phone numbers, moving, changes in family structure).
#
# ### 8. **Prepare for Different Scenarios**
#    - Consider how your plan might change based on different types of emergencies. For example, during a wildfire, you may need to evacuate quickly, while during a severe storm, you may need to stay put.
#
# ### 9. **Educate Family Members**
#    - Ensure that all family members, including children, understand the plan and know how to use the communication tools you’ve chosen.
#
# ### 10. **Keep Emergency Supplies Ready**
#    - Maintain an emergency kit that includes essential items like water, food, first aid supplies, flashlights, batteries, and a copy of your communication plan.
#
# ### 11. **Utilize Technology**
#    - Consider using apps designed for emergency communication and alerts. Some apps allow families to share their locations and communicate even when cell service is down.
#
# ### 12. **Stay Informed**
#    - Sign up for local emergency alerts and notifications to stay informed about potential threats in your area.
#
# By following these steps, you can create a comprehensive family emergency communication plan that helps ensure everyone knows what to do and how to stay connected during a crisis.
# TRUE: Start by talking with your family and support network about how you will contact each other and where to meet if separated. Keep a list of emergency contacts in your wallet and post important numbers near your phone. Use the Make a Plan Form from Ready.gov.
#
# Q: How can I stay informed during a disaster if I don't have a smartphone?
# AI: Staying informed during a disaster without a smartphone can be challenging, but there are several effective methods you can use:
#
# 1. **Battery-Powered or Hand-Crank Radio**: Invest in a battery-powered or hand-crank emergency radio. These radios can receive NOAA Weather Radio broadcasts, which provide continuous updates on weather conditions and emergency information.
#
# 2. **Local News Radio Stations**: Tune in to local AM or FM radio stations that provide news updates. Many stations will cover emergency situations and provide important information.
#
# 3. **Television**: If you have access to a television, local news channels often provide live coverage and updates during disasters. Keep a battery-operated TV or a generator handy if you anticipate power outages.
#
# 4. **Community Alert Systems**: Check if your community has a local alert system that sends out notifications via landline phones or through sirens. Many communities have systems in place to alert residents of emergencies.
#
# 5. **Landline Phones**: Use a landline phone to call friends, family, or neighbors to get updates on the situation. They may have access to information that you do not.
#
# 6. **Public Libraries**: If it’s safe to do so, visit your local library. They often have access to news sources and may provide information on community resources during a disaster.
#
# 7. **Community Centers**: Local community centers or shelters may have information available and can serve as a hub for updates and resources.
#
# 8. **Word of Mouth**: Stay connected with neighbors and community members. They can share information and updates about the situation.
#
# 9. **Emergency Services**: Keep the contact numbers for local emergency services handy. They can provide information on what to do during a disaster.
#
# 10. **Prepare in Advance**: Before a disaster strikes, gather information about local emergency plans, evacuation routes, and resources. Create a communication plan with family and friends.
#
# By utilizing these methods, you can stay informed and make better decisions during a disaster, even without a smartphone.
# TRUE: Listen to local radio or television for emergency broadcasts. Consider purchasing a weather radio. Join local community groups or CERTs to receive alerts.
#
# Q: What should I do if I am unable to evacuate during an emergency?
# AI: If you find yourself unable to evacuate during an emergency, it's important to stay calm and take the following steps to ensure your safety:
#
# 1. **Stay Informed**: Keep a battery-powered radio, smartphone, or other devices handy to receive updates from local authorities. Follow official instructions and updates regarding the emergency.
#
# 2. **Find a Safe Location**: Identify a safe area within your home or building. This could be a room with no windows or a higher floor if there is flooding. Make sure it is away from potential hazards.
#
# 3. **Prepare Your Shelter**: Gather essential supplies, including water, non-perishable food, a flashlight, batteries, a first aid kit, and any necessary medications. If you have pets, ensure you have supplies for them as well.
#
# 4. **Seal Off the Area**: If necessary, seal windows and doors with duct tape and plastic sheeting to protect against smoke, flooding, or other hazards. This can help keep out harmful elements.
#
# 5. **Signal for Help**: If you are in a situation where you cannot evacuate, make your presence known. Use a whistle, flashlight, or signal from a window to attract attention if rescue teams are nearby.
#
# 6. **Stay Low**: If there is smoke or gas, stay low to the ground where the air is clearer. Cover your mouth and nose with a cloth if necessary.
#
# 7. **Stay Together**: If you are with others, stay together and keep communication open. This can help maintain morale and ensure everyone is accounted for.
#
# 8. **Conserve Resources**: Ration your food and water supplies, and use your flashlight and other resources sparingly to ensure they last as long as possible.
#
# 9. **Prepare for Rescue**: If you hear rescuers, make noise to alert them to your location. If you are in a building, stay near a window or door where you can be seen.
#
# 10. **Stay Calm**: Panic can lead to poor decision-making. Focus on what you can control and take things one step at a time.
#
# Remember, every emergency is different, so adapt these steps to your specific situation. Always prioritize your safety and the safety of those around you.
# TRUE: Shelter in place in the safest room in your home, and inform your support network of your situation. Keep a radio or phone handy for updates from officials.
#
# Q: What items should older adults include in an emergency preparedness kit?
# AI: Creating an emergency preparedness kit for older adults is essential to ensure their safety and well-being during emergencies. Here are some key items to include:
#
# 1. **Water and Food:**
#    - At least a three-day supply of water (one gallon per person per day).
#    - Non-perishable food items (canned goods, granola bars, dried fruits, etc.) that are easy to open and consume.
#
# 2. **Medications:**
#    - A supply of prescription medications (at least a week's worth).
#    - Over-the-counter medications (pain relievers, antacids, etc.).
#    - A list of all medications, dosages, and any allergies.
#
# 3. **Medical Supplies:**
#    - First aid kit (band-aids, antiseptic wipes, gauze, etc.).
#    - Any necessary medical equipment (e.g., cane, walker, hearing aids, glasses).
#    - Extra batteries for hearing aids or other devices.
#
# 4. **Personal Care Items:**
#    - Hygiene products (toothbrush, toothpaste, soap, hand sanitizer, etc.).
#    - Incontinence supplies if needed.
#
# 5. **Communication Tools:**
#    - A fully charged cell phone with a portable charger.
#    - A list of emergency contacts, including family members and caregivers.
#    - A whistle to signal for help.
#
# 6. **Important Documents:**
#    - Copies of identification (driver’s license, Medicare card).
#    - Emergency contact information.
#    - Medical records and insurance information.
#
# 7. **Comfort Items:**
#    - A blanket or sleeping bag.
#    - A flashlight with extra batteries.
#    - A radio (battery-operated or hand-crank) for updates.
#
# 8. **Cash:**
#    - Small denominations of cash, as ATMs may not be accessible during emergencies.
#
# 9. **Transportation Needs:**
#    - A list of accessible transportation options in the area.
#    - A mobility device if needed (e.g., wheelchair, scooter).
#
# 10. **Special Considerations:**
#     - Items for pets if applicable (food, water, leash).
#     - Any specific items related to personal hobbies or interests that may provide comfort.
#
# 11. **Emergency Plan:**
#     - A written emergency plan that includes evacuation routes, meeting places, and how to communicate with family members.
#
# It's important to regularly check and update the kit, ensuring that food and medications are not expired and that all items are in good condition. Additionally, older adults should be familiar with the contents of their kit and have a plan for how to use it in case of an emergency.
# TRUE: Pack water, non-perishable food, medications, extra batteries, flashlight, important documents (insurance, IDs), pet supplies, a first aid kit, and a written list of your medications and contacts.
#
# Q: How can older adults engage their support network for disaster preparedness?
# AI: Engaging a support network for disaster preparedness is crucial for older adults, as they may face unique challenges during emergencies. Here are several strategies to help older adults effectively engage their support network:
#
# 1. **Identify Key Contacts**: Encourage older adults to identify family members, friends, neighbors, and community organizations that can provide assistance during a disaster.
#
# 2. **Create a Communication Plan**: Help them develop a communication plan that includes phone numbers, email addresses, and social media contacts. Ensure they know how to reach their support network in case of an emergency.
#
# 3. **Organize Meetings**: Facilitate regular meetings with their support network to discuss disaster preparedness plans, share resources, and review emergency contacts. This can be done in person or virtually.
#
# 4. **Educate on Preparedness**: Provide information on disaster preparedness, including creating emergency kits, evacuation plans, and understanding local hazards. Encourage older adults to share this information with their support network.
#
# 5. **Practice Drills**: Organize practice drills with their support network to ensure everyone knows their roles and responsibilities during a disaster. This can help build confidence and familiarity with the plan.
#
# 6. **Utilize Technology**: Encourage the use of technology, such as group messaging apps or social media, to keep everyone informed and connected. This can be especially useful for quick updates during an emergency.
#
# 7. **Leverage Community Resources**: Connect older adults with local organizations that focus on disaster preparedness, such as community centers, senior organizations, or local emergency management agencies.
#
# 8. **Encourage Mutual Aid**: Promote the idea of mutual aid within their support network, where members can offer assistance to one another, such as helping with transportation, providing supplies, or checking in during emergencies.
#
# 9. **Discuss Mobility and Accessibility**: Address any mobility or accessibility concerns that older adults may have and ensure their support network is aware of these needs when planning for emergencies.
#
# 10. **Stay Informed**: Encourage older adults to stay informed about local disaster plans and resources, and share this information with their support network to ensure everyone is on the same page.
#
# 11. **Create a Buddy System**: Establish a buddy system where older adults are paired with someone in their support network who can check on them during emergencies and assist as needed.
#
# 12. **Encourage Regular Check-Ins**: Suggest that older adults and their support network establish a routine for regular check-ins, especially during severe weather or other potential emergencies.
#
# By taking these steps, older adults can strengthen their support network and enhance their overall disaster preparedness, ensuring they have the assistance they need during emergencies.
# TRUE: Share your emergency plan with family, friends, neighbors, and caregivers. Make sure someone has a spare key and knows how to help with your medical equipment. Practice your plan together regularly.
#
# Q: What special steps should older adults in rural areas take to prepare for disasters?
# AI: Older adults in rural areas face unique challenges when preparing for disasters due to factors such as limited access to resources, healthcare, and transportation. Here are some special steps they can take to prepare:
#
# 1. **Create a Personal Emergency Plan**:
#    - Develop a comprehensive emergency plan that includes communication methods, evacuation routes, and designated meeting places.
#    - Ensure that the plan is easy to understand and accessible.
#
# 2. **Build a Support Network**:
#    - Connect with neighbors, family, and friends to establish a support system. Regularly check in with each other, especially during emergencies.
#    - Join local community groups or organizations that focus on disaster preparedness.
#
# 3. **Stay Informed**:
#    - Sign up for local alerts and warnings through community emergency management systems.
#    - Keep a battery-operated or hand-crank radio to receive updates during power outages.
#
# 4. **Prepare an Emergency Kit**:
#    - Assemble a disaster supply kit that includes essential items such as medications, first aid supplies, non-perishable food, water, flashlight, batteries, and personal hygiene items.
#    - Include important documents (e.g., identification, medical records) in a waterproof container.
#
# 5. **Plan for Medical Needs**:
#    - Ensure an adequate supply of medications and medical supplies, and have a plan for accessing healthcare during a disaster.
#    - Consider a medical alert system for emergencies.
#
# 6. **Transportation Arrangements**:
#    - Identify reliable transportation options for evacuating if necessary. This may include arranging rides with neighbors or local services.
#    - Keep a list of local transportation services that can assist during emergencies.
#
# 7. **Home Safety Modifications**:
#    - Make necessary modifications to the home to enhance safety, such as securing heavy furniture, installing smoke detectors, and ensuring clear escape routes.
#    - Consider backup power sources, such as generators, for medical equipment.
#
# 8. **Practice Drills**:
#    - Conduct regular emergency drills to ensure familiarity with the plan and to identify any areas that need improvement.
#    - Involve family members or caregivers in these drills.
#
# 9. **Stay Connected**:
#    - Use technology to stay connected with family and friends. Regular check-ins can provide emotional support and ensure safety.
#    - Consider using social media or messaging apps to share information quickly.
#
# 10. **Know Local Resources**:
#     - Familiarize yourself with local emergency services, shelters, and resources available in the community.
#     - Keep a list of contact numbers for local emergency services, neighbors, and family members.
#
# 11. **Mental Health Preparedness**:
#     - Prepare for the emotional impact of disasters by having coping strategies in place. This may include mindfulness practices, access to counseling, or support groups.
#
# 12. **Community Involvement**:
#     - Participate in local disaster preparedness workshops or training sessions to learn more about specific risks and response strategies in the area.
#
# By taking these steps, older adults in rural areas can enhance their preparedness for disasters and improve their resilience in the face of emergencies.
# TRUE: Stock up on supplies, arrange transportation options in advance, create a backup communications plan for power/internet outages, and build a network of neighbors who can help during emergencies.

# %%
import json

# --- Load evaluation results ---
with open("evaluation_results.json", "r") as f:
    results = json.load(f)

# --- Print results in a readable table ---
print(f"{'Query':<50} | {'AI Response':<60} | {'Embed Score':<12} | {'Similarity':<10} | {'LLM Score':<9} | {'Error Score':<11}")
print("-" * 170)

for r in results:
    # Truncate long query and AI response for display
    query_preview = (r['query'][:47] + "...") if len(r['query']) > 50 else r['query']
    ai_preview = (r['ai_answer'][:57] + "...") if len(r['ai_answer']) > 60 else r['ai_answer']

    # Ensure LLM score is a float
    try:
        llm_score = float(r.get('llm_score', 0))
    except (TypeError, ValueError):
        llm_score = 0.0

    # Calculate Error Score
    error_score = round(1 - llm_score, 2)

    print(f"{query_preview:<50} | {ai_preview:<60} | {r['embedding_score']:<12} | {r['similarity']:<10} | {llm_score:<9} | {error_score:<11}")

# --- Optional: Show only incorrect answers with details ---
print("\n❌ Incorrect answers (Embed Score = 0):")
for r in results:
    if r['embedding_score'] == 0:
        print(f"\nQ: {r['query']}")
        print(f"AI: {r['ai_answer']}")
        print(f"TRUE: {r['true_answer']}")
        try:
            llm_score = float(r.get('llm_score', 0))
        except (TypeError, ValueError):
            llm_score = 0.0
        print(f"Error Score: {round(1 - llm_score, 2)}")
# Out:
# Query                                              | AI Response                                                  | Embed Score  | Similarity | LLM Score | Error Score
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# What steps does the PEMA Disaster Resource Guid... | The PEMA Disaster Resource Guide typically recommends the... | 0.5          | 0.76       | 0.5       | 0.5
# According to the PA 211 Emergency Resource Manu... | Residents of ZIP code 17104 can access ice and mobile pho... | 0.5          | 0.771      | 0.5       | 0.5
# What shelter options are listed in the PEMA Eme... | I don't have access to real-time databases or specific di... | 0.5          | 0.728      | 0.5       | 0.5
# How does the PEMA guide recommend seniors in Ha... | The PEMA (Pennsylvania Emergency Management Agency) guide... | 0.5          | 0.715      | 0.5       | 0.5
# Which organizations provide water delivery or p... | To find specific organizations that provide water deliver... | 0            | 0.647      | 0.5       | 0.5
# What school or community-based child meal progr... | I don't have access to real-time data or specific documen... | 0.5          | 0.788      | 0.5       | 0.5
# Where can culturally appropriate food be access... | To find culturally appropriate food after a disaster in H... | 0.5          | 0.75       | 0.5       | 0.5
# What guidance does PEMA provide on water safety... | The Pennsylvania Emergency Management Agency (PEMA) provi... | 0.5          | 0.783      | 1.0       | 0.0
# How does PA 211 assist individuals needing wate... | PA 211 provides critical assistance to individuals who re... | 0.5          | 0.801      | 0.5       | 0.5
# What does the Red Cross and PEMA shelter guide ... | The Red Cross and PEMA (Pennsylvania Emergency Management... | 0.5          | 0.865      | 0.5       | 0.5
# Where are crisis shelters for domestic violence... | To find crisis shelters for domestic violence survivors d... | 0.5          | 0.752      | 0.5       | 0.5
# What are the recommended first aid or urgent ca... | I don't have access to specific documents, including the ... | 0            | 0.666      | 0.5       | 0.5
# According to the PA 211 Medication Emergency FA... | During a disaster, individuals can obtain emergency insul... | 0.5          | 0.701      | 0.5       | 0.5
# What mental health hotlines or crisis counselin... | In the Disaster Behavioral Health section of the PA 211 E... | 0.5          | 0.816      | 0.5       | 0.5
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide recommends that residents... | 0.5          | 0.746      | 0.5       | 0.5
# How does PA 211 recommend accessing communicati... | PA 211 recommends several strategies for accessing commun... | 0.5          | 0.757      | 0.5       | 0.5
# What evacuation resources are described for peo... | I don't have access to specific documents, including the ... | 0.5          | 0.723      | 0.5       | 0.5
# According to PEMA Flood Preparedness Resource, ... | Residents in Harrisburg can pick up free sandbags or floo... | 0.5          | 0.868      | 0.5       | 0.5
# What steps should be taken to file a FEMA disas... | Filing a FEMA disaster claim involves several steps, as o... | 0.5          | 0.743      | 0.5       | 0.5
# Does the PA 211 Disaster Support Guide indicate... | Yes, the PA 211 Disaster Support Guide indicates that und... | 0.5          | 0.857      | 1.0       | 0.0
# Where can individuals with oxygen tanks or powe... | Individuals with oxygen tanks or power-dependent medical ... | 0.5          | 0.852      | 0.5       | 0.5
# What instructions does the PEMA Home Damage Ass... | The PEMA Home Damage Assessment Guide provides specific i... | 0.5          | 0.837      | 0.5       | 0.5
# According to the PA 211 Infant and Family Emerg... | In Harrisburg, families can get diapers and baby formula ... | 0.5          | 0.813      | 0.5       | 0.5
# Where does the PEMA Community Resource Guide su... | The PEMA Community Resource Guide suggests that individua... | 0.5          | 0.869      | 1.0       | 0.0
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ typically provides vario... | 0.5          | 0.869      | 0.5       | 0.5
# What steps does the PEMA Disaster Resource Guid... | The PEMA Disaster Resource Guide typically recommends the... | 0.5          | 0.82       | 0.5       | 0.5
# According to the PA 211 Emergency Resource Manu... | Residents of ZIP code 17104 can access ice and mobile pho... | 0.5          | 0.803      | 0.5       | 0.5
# What shelter options are listed in the PEMA Eme... | I don't have access to real-time databases or specific di... | 0.5          | 0.741      | 0.5       | 0.5
# How does the PEMA guide recommend seniors in Ha... | The PEMA (Pennsylvania Emergency Management Agency) guide... | 0.5          | 0.719      | 0.5       | 0.5
# Which organizations provide water delivery or p... | To find specific organizations that provide water deliver... | 0            | 0.649      | 0.5       | 0.5
# What school or community-based child meal progr... | I don't have access to real-time data or specific documen... | 0.5          | 0.786      | 0.5       | 0.5
# Where can culturally appropriate food be access... | To find culturally appropriate food after a disaster in H... | 0.5          | 0.747      | 0.5       | 0.5
# What guidance does PEMA provide on water safety... | The Pennsylvania Emergency Management Agency (PEMA) provi... | 0.5          | 0.787      | 1.0       | 0.0
# How does PA 211 assist individuals needing wate... | PA 211 provides critical assistance to individuals who re... | 0.5          | 0.784      | 0.5       | 0.5
# What does the Red Cross and PEMA shelter guide ... | The Red Cross and PEMA (Pennsylvania Emergency Management... | 0.5          | 0.863      | 0.5       | 0.5
# Where are crisis shelters for domestic violence... | To find crisis shelters for domestic violence survivors d... | 0.5          | 0.753      | 0.5       | 0.5
# What are the recommended first aid or urgent ca... | I don't have access to specific documents, including the ... | 0            | 0.668      | 0.5       | 0.5
# According to the PA 211 Medication Emergency FA... | During a disaster, individuals can obtain emergency insul... | 0            | 0.65       | 0.5       | 0.5
# What mental health hotlines or crisis counselin... | In the Disaster Behavioral Health section of the PA 211 E... | 0.5          | 0.811      | 0.5       | 0.5
# Where does the PEMA Winter Emergency Guide reco... | The PEMA Winter Emergency Guide recommends that residents... | 0.5          | 0.765      | 0.5       | 0.5
# How does PA 211 recommend accessing communicati... | PA 211 recommends several strategies for accessing commun... | 0.5          | 0.74       | 0.5       | 0.5
# What evacuation resources are described for peo... | I'm sorry, but I can't access external documents or speci... | 0.5          | 0.701      | 0.5       | 0.5
# According to PEMA Flood Preparedness Resource, ... | Residents in Harrisburg can pick up free sandbags or floo... | 0.5          | 0.868      | 0.5       | 0.5
# What steps should be taken to file a FEMA disas... | Filing a FEMA disaster claim involves several steps, as o... | 0.5          | 0.741      | 0.5       | 0.5
# Does the PA 211 Disaster Support Guide indicate... | Yes, the PA 211 Disaster Support Guide indicates that und... | 0.5          | 0.857      | 1.0       | 0.0
# Where can individuals with oxygen tanks or powe... | Individuals with oxygen tanks or power-dependent medical ... | 0.5          | 0.844      | 0.5       | 0.5
# What instructions does the PEMA Home Damage Ass... | The PEMA Home Damage Assessment Guide provides specific i... | 0.5          | 0.831      | 0.5       | 0.5
# According to the PA 211 Infant and Family Emerg... | In Harrisburg, families can obtain diapers and baby formu... | 0.5          | 0.819      | 0.5       | 0.5
# Where does the PEMA Community Resource Guide su... | The PEMA Community Resource Guide suggests that individua... | 0.5          | 0.869      | 1.0       | 0.0
# What options are presented in the PA 211 Disast... | The PA 211 Disaster Recovery FAQ typically provides vario... | 0.5          | 0.868      | 0.5       | 0.5
# Can I volunteer to help others in a disaster?      | Yes, you can definitely volunteer to help others in a dis... | 0            | 0.524      | 0.5       | 0.5
# How can older adults assess their personal need... | Assessing personal needs before a disaster is crucial for... | 0.5          | 0.713      | 1.0       | 0.0
# What steps should I take to create a family eme... | Creating a family emergency communication plan is essenti... | 0            | 0.684      | 1.0       | 0.0
# If I have a disability, how can I ensure my eme... | Ensuring that your emergency kit is accessible if you hav... | 0.5          | 0.704      | 1.0       | 0.0
# How can I stay informed during a disaster if I ... | Staying informed during a disaster without a smartphone c... | 0            | 0.646      | 1.0       | 0.0
# What should I do if I am unable to evacuate dur... | If you find yourself unable to evacuate during an emergen... | 0            | 0.661      | 1.0       | 0.0
# What items should older adults include in an em... | Creating an emergency preparedness kit for older adults i... | 0            | 0.691      | 1.0       | 0.0
# How can older adults engage their support netwo... | Engaging a support network for disaster preparedness is c... | 0            | 0.566      | 1.0       | 0.0
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0            | 0.641      | 1.0       | 0.0
# Where can I get help building an emergency plan... | If you have limited resources and need help building an e... | 0.5          | 0.733      | 1.0       | 0.0
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.729      | 1.0       | 0.0
# How can older adults assess their personal need... | Assessing personal needs before a disaster is crucial for... | 0.5          | 0.722      | 1.0       | 0.0
# What steps should I take to create a family eme... | Creating a family emergency communication plan is essenti... | 0            | 0.69       | 1.0       | 0.0
# If I have a disability, how can I ensure my eme... | Ensuring that your emergency kit is accessible if you hav... | 0.5          | 0.701      | 1.0       | 0.0
# How can I stay informed during a disaster if I ... | Staying informed during a disaster without a smartphone c... | 0            | 0.648      | 1.0       | 0.0
# What should I do if I am unable to evacuate dur... | If you find yourself unable to evacuate during an emergen... | 0            | 0.644      | 1.0       | 0.0
# What items should older adults include in an em... | Creating an emergency preparedness kit for older adults i... | 0            | 0.684      | 1.0       | 0.0
# How can older adults engage their support netwo... | Engaging a support network for disaster preparedness is c... | 0            | 0.589      | 1.0       | 0.0
# What special steps should older adults in rural... | Older adults in rural areas face unique challenges when p... | 0            | 0.637      | 1.0       | 0.0
# Where can I get help building an emergency plan... | If you have limited resources and need help building an e... | 0.5          | 0.72       | 1.0       | 0.0
# How can I include my pet or service animal in m... | Including your pet or service animal in your emergency pl... | 0.5          | 0.737      | 1.0       | 0.0
#
# ❌ Incorrect answers (Embed Score = 0):
#
# Q: Which organizations provide water delivery or pickup for vulnerable residents, as referenced in the PA 211 Resource Directory for ZIP 17104?
# AI: To find specific organizations that provide water delivery or pickup for vulnerable residents in the ZIP code 17104, you would typically refer to the PA 211 Resource Directory directly. PA 211 is a resource that connects individuals with local services, including those for water delivery and other essential needs.
#
# You can visit the PA 211 website or call their helpline to get the most accurate and up-to-date information on organizations in your area that offer these services. They can provide details on local nonprofits, community organizations, or government programs that assist vulnerable residents with water access.
# TRUE: The PA 211 Resource Directory identifies the Farm Show Complex as an emergency bottled water distribution site and lists United Way and VOAD as coordinators for home delivery to seniors and people with disabilities.
# Error Score: 0.5
#
# Q: What are the recommended first aid or urgent care alternatives when local hospitals are over capacity, per the PEMA Emergency Medical Resources PDF?
# AI: I don't have access to specific documents, including the PEMA Emergency Medical Resources PDF. However, I can provide general recommendations for first aid and urgent care alternatives when local hospitals are over capacity:
#
# 1. **Urgent Care Clinics**: These facilities can handle non-life-threatening conditions and are often less crowded than emergency rooms.
#
# 2. **Telemedicine Services**: Many healthcare providers offer virtual consultations, which can be a quick way to get medical advice without visiting a facility.
#
# 3. **Community Health Centers**: These centers often provide a range of services and may have shorter wait times.
#
# 4. **Pharmacies with Health Clinics**: Some pharmacies have walk-in clinics that can treat minor ailments and provide basic health services.
#
# 5. **Home Care**: For minor injuries or illnesses, consider home care options, including over-the-counter medications and first aid supplies.
#
# 6. **Local Health Departments**: They may offer resources or guidance on where to seek care when hospitals are overwhelmed.
#
# 7. **First Aid Kits**: Having a well-stocked first aid kit at home can help manage minor injuries effectively.
#
# 8. **Emergency Services**: If a situation is life-threatening, always call emergency services, as they can provide immediate assistance.
#
# For the most accurate and specific information, please refer to the PEMA Emergency Medical Resources PDF or your local health department's guidelines.
# TRUE: The PEMA Emergency Medical Resources PDF recommends seeking mobile medical units or urgent care pop-ups coordinated by UPMC or Penn State Health, which are activated when hospitals are at capacity. Locations rotate and are announced through 211 and local emergency alerts.
# Error Score: 0.5
#
# Q: Which organizations provide water delivery or pickup for vulnerable residents, as referenced in the PA 211 Resource Directory for ZIP 17104?
# AI: To find specific organizations that provide water delivery or pickup for vulnerable residents in the ZIP code 17104, you would typically refer to the PA 211 Resource Directory directly. PA 211 is a resource that connects individuals with local services, including those for water delivery and other essential needs.
#
# You can visit the PA 211 website or call their helpline to get the most accurate and up-to-date information on organizations in your area that offer these services. They can provide details on local nonprofits, government programs, and community resources that assist vulnerable residents with water access.
# TRUE: The PA 211 Resource Directory identifies the Farm Show Complex as an emergency bottled water distribution site and lists United Way and VOAD as coordinators for home delivery to seniors and people with disabilities.
# Error Score: 0.5
#
# Q: What are the recommended first aid or urgent care alternatives when local hospitals are over capacity, per the PEMA Emergency Medical Resources PDF?
# AI: I don't have access to specific documents, including the PEMA Emergency Medical Resources PDF. However, I can provide general recommendations for first aid or urgent care alternatives when local hospitals are over capacity:
#
# 1. **Urgent Care Clinics**: These facilities can handle non-life-threatening conditions and are often less crowded than emergency rooms.
#
# 2. **Telemedicine Services**: Many healthcare providers offer virtual consultations, which can be a quick way to get medical advice without visiting a facility.
#
# 3. **Walk-in Clinics**: Pharmacies and retail stores often have walk-in clinics that can treat minor injuries and illnesses.
#
# 4. **Community Health Centers**: These centers provide a range of health services and may have shorter wait times.
#
# 5. **First Aid Kits**: For minor injuries, having a well-stocked first aid kit can help manage situations at home.
#
# 6. **Local Health Departments**: They may offer resources or guidance on where to seek care when hospitals are overwhelmed.
#
# 7. **Home Care**: For minor ailments, self-care measures and over-the-counter medications can be effective.
#
# 8. **Emergency Medical Services (EMS)**: If a situation is life-threatening, always call 911 or your local emergency number, as EMS can provide immediate care and transport.
#
# For the most accurate and specific information, please refer to the PEMA Emergency Medical Resources PDF or your local health department's guidelines.
# TRUE: The PEMA Emergency Medical Resources PDF recommends seeking mobile medical units or urgent care pop-ups coordinated by UPMC or Penn State Health, which are activated when hospitals are at capacity. Locations rotate and are announced through 211 and local emergency alerts.
# Error Score: 0.5
#
# Q: According to the PA 211 Medication Emergency FAQ, how can individuals get emergency insulin or prescription refills during a disaster?
# AI: During a disaster, individuals can obtain emergency insulin or prescription refills by following these steps:
#
# 1. **Contact Your Pharmacy**: Reach out to your local pharmacy to inquire about their policies for emergency refills. Many pharmacies have protocols in place for providing medications during emergencies.
#
# 2. **State Emergency Services**: Check with state or local emergency services, as they may have resources or programs to assist individuals in obtaining necessary medications during a disaster.
#
# 3. **Healthcare Providers**: Contact your healthcare provider or doctor’s office. They may be able to provide a prescription refill or direct you to resources for obtaining your medication.
#
# 4. **Emergency Shelters**: If you are in an emergency shelter, staff may be able to assist you in accessing your medications.
#
# 5. **Insurance Provider**: Reach out to your health insurance provider to understand your coverage for emergency medication refills.
#
# 6. **Local Health Departments**: Some local health departments may have programs to help individuals access medications during emergencies.
#
# It's important to plan ahead and have a strategy in place for accessing medications during potential disasters.
# TRUE: The PA 211 Medication Emergency FAQ states that residents can contact 211 to be referred to local clinics like Hamilton Health Center, which are authorized for prescription replacement. Emergency pharmacy partners can provide insulin refills with proof of need.
# Error Score: 0.5
#
# Q: Can I volunteer to help others in a disaster?
# AI: Yes, you can definitely volunteer to help others in a disaster. Many organizations and agencies seek volunteers to assist in disaster response and recovery efforts. Here are some steps you can take to get involved:
#
# 1. **Research Local Organizations**: Look for local non-profits, community organizations, or national agencies like the American Red Cross, Team Rubicon, or local emergency management offices that coordinate disaster response efforts.
#
# 2. **Get Trained**: Some organizations offer training programs for volunteers. This training can prepare you for various roles, such as providing first aid, managing supplies, or helping with logistics.
#
# 3. **Register as a Volunteer**: Many organizations have a volunteer registration process. Sign up to be on their list of volunteers so they can contact you when help is needed.
#
# 4. **Stay Informed**: Follow local news and social media channels to stay updated on disasters in your area and the needs of affected communities.
#
# 5. **Be Prepared**: If you plan to volunteer during a disaster, ensure you have the necessary supplies, such as food, water, and personal safety gear, and be ready to respond quickly.
#
# 6. **Consider Your Skills**: Think about what skills you can offer. Medical professionals, counselors, logistics experts, and those with experience in construction or food service can be particularly valuable.
#
# 7. **Be Flexible**: Disaster response can be unpredictable, so be prepared to adapt to changing needs and situations.
#
# 8. **Support Recovery Efforts**: Volunteering doesn’t just happen during the immediate response phase. Many organizations also need help with long-term recovery efforts, which can last for months or even years.
#
# Remember to prioritize your safety and well-being while volunteering, and follow the guidance of local authorities and organizations.
# TRUE: Yes! Call 2-1-1 or visit the PA VOAD website to sign up for: Debris removal crews, shelter assistance, and food and supply packaging. Training and background checks may be required.
# Error Score: 0.5
#
# Q: What steps should I take to create a family emergency communication plan?
# AI: Creating a family emergency communication plan is essential for ensuring that all family members know how to stay in touch and where to meet in case of an emergency. Here are the steps you can take to create an effective plan:
#
# ### 1. **Assess Your Risks**
#    - Identify potential emergencies that could affect your family, such as natural disasters (earthquakes, floods, hurricanes), fires, or other crises.
#    - Consider your location and any specific risks associated with it.
#
# ### 2. **Establish Communication Methods**
#    - **Primary Contact:** Designate a primary contact person outside your immediate area (a relative or friend) who can help relay information.
#    - **Communication Tools:** Decide on the methods of communication (text, phone calls, social media, messaging apps) and ensure everyone knows how to use them.
#    - **Emergency Apps:** Consider using emergency apps that can help with communication and information sharing.
#
# ### 3. **Create a Family Contact List**
#    - Compile a list of important contacts, including family members, friends, neighbors, and emergency services.
#    - Include phone numbers, email addresses, and physical addresses.
#
# ### 4. **Establish Meeting Points**
#    - Identify safe locations where family members can meet after an emergency, both near your home and further away in case of evacuation.
#    - Make sure everyone knows how to get to these locations.
#
# ### 5. **Develop a Communication Plan**
#    - Outline how family members will communicate during an emergency. For example, if phone lines are down, you might rely on text messages or social media.
#    - Discuss how to check in with each other and how often to do so.
#
# ### 6. **Practice the Plan**
#    - Conduct regular drills to practice your communication plan and ensure everyone knows their roles and responsibilities.
#    - Review the plan periodically and update it as necessary.
#
# ### 7. **Prepare an Emergency Kit**
#    - Assemble an emergency kit that includes essential items such as water, food, first aid supplies, flashlights, batteries, and important documents.
#    - Ensure that everyone knows where the kit is stored.
#
# ### 8. **Educate Family Members**
#    - Teach family members about the plan, including how to use communication tools and what to do in various emergency scenarios.
#    - Discuss the importance of staying calm and following the plan during an emergency.
#
# ### 9. **Stay Informed**
#    - Keep up to date with local emergency services and alerts. Sign up for local emergency notifications if available.
#    - Review and update your plan regularly, especially after any changes in family circumstances or after an emergency.
#
# ### 10. **Document the Plan**
#    - Write down the communication plan and distribute copies to all family members.
#    - Consider keeping a digital copy accessible on a shared platform or cloud service.
#
# By following these steps, you can create a comprehensive family emergency communication plan that helps ensure everyone stays connected and safe during a crisis.
# TRUE: Start by talking with your family and support network about how you will contact each other and where to meet if separated. Keep a list of emergency contacts in your wallet and post important numbers near your phone. Use the Make a Plan Form from Ready.gov.
# Error Score: 0.0
#
# Q: How can I stay informed during a disaster if I don't have a smartphone?
# AI: Staying informed during a disaster without a smartphone can be challenging, but there are several effective methods you can use:
#
# 1. **Battery-Powered or Hand-Crank Radio**: Invest in a battery-powered or hand-crank emergency radio. These radios can receive NOAA Weather Radio broadcasts, which provide real-time updates on weather conditions and emergency alerts.
#
# 2. **Local News Radio Stations**: Tune in to local AM or FM radio stations that provide news updates. Many stations will cover emergency situations and provide information on evacuations, shelters, and safety tips.
#
# 3. **Television**: If you have access to a television, local news channels often provide continuous coverage during disasters. Keep a battery-operated TV or a portable one if you anticipate power outages.
#
# 4. **Community Alert Systems**: Sign up for local community alert systems that may send notifications via landline phones or through other means. Check with your local government or emergency management office for available services.
#
# 5. **Landline Phones**: Keep a landline phone available, as it may still work during power outages when mobile networks may be down. Use it to call friends, family, or local authorities for updates.
#
# 6. **Neighborhood Watch or Community Groups**: Stay connected with neighbors or local community groups. They can share information and updates about the situation in your area.
#
# 7. **Public Bulletin Boards**: Check community centers, libraries, or other public places for bulletin boards that may have posted updates and information about the disaster.
#
# 8. **Emergency Services**: Keep the contact numbers for local emergency services handy. You can call them for information or assistance.
#
# 9. **Local Government Websites**: If you have access to a computer, check your local government’s website for updates. Many municipalities provide information on their websites during emergencies.
#
# 10. **Preparedness Kits**: Prepare an emergency kit that includes essential supplies, a flashlight, batteries, and a first aid kit. This will help you stay safe and informed during a disaster.
#
# By utilizing these methods, you can stay informed and connected during a disaster even without a smartphone.
# TRUE: Listen to local radio or television for emergency broadcasts. Consider purchasing a weather radio. Join local community groups or CERTs to receive alerts.
# Error Score: 0.0
#
# Q: What should I do if I am unable to evacuate during an emergency?
# AI: If you find yourself unable to evacuate during an emergency, here are some steps you can take to ensure your safety:
#
# 1. **Stay Informed**: Keep updated on the situation through reliable sources such as local news, emergency services, or weather alerts. Use a battery-powered radio if power is out.
#
# 2. **Find a Safe Location**: Identify a safe area in your home or building. This could be a room with no windows or a designated safe space. If you are in a multi-story building, consider moving to a higher floor if flooding is a concern.
#
# 3. **Prepare Your Space**:
#    - Close and secure windows and doors to prevent outside hazards from entering.
#    - Use towels or blankets to seal gaps under doors to keep out smoke or water.
#    - If applicable, turn off utilities (gas, water, electricity) to prevent further hazards.
#
# 4. **Gather Supplies**: Collect essential items such as:
#    - Water and non-perishable food
#    - First aid kit
#    - Flashlights and batteries
#    - Medications
#    - Important documents (ID, insurance, etc.)
#    - A whistle to signal for help
#
# 5. **Communicate**: If possible, inform family or friends of your situation. Use text messages or social media if phone lines are congested.
#
# 6. **Stay Calm**: Keep a clear head and try to remain calm. This will help you think more clearly and make better decisions.
#
# 7. **Signal for Help**: If you are in a situation where you cannot evacuate, make noise or use a signal (like a flashlight or a brightly colored cloth) to attract attention.
#
# 8. **Follow Emergency Protocols**: If you have a plan in place for emergencies, follow it. This may include specific actions based on the type of emergency (e.g., sheltering in place during a tornado).
#
# 9. **Stay Low**: If there is smoke, stay low to the ground to avoid inhalation. Cover your mouth with a cloth if necessary.
#
# 10. **Be Prepared to Move**: If conditions worsen, be ready to move to a different location within your home or building if it becomes unsafe.
#
# 11. **Wait for Help**: If you have signaled for help, stay in your safe location and wait for emergency responders to arrive.
#
# Remember, your safety is the priority. Always assess your situation and make decisions based on the immediate risks you face.
# TRUE: Shelter in place in the safest room in your home, and inform your support network of your situation. Keep a radio or phone handy for updates from officials.
# Error Score: 0.0
#
# Q: What items should older adults include in an emergency preparedness kit?
# AI: Creating an emergency preparedness kit for older adults is essential to ensure their safety and well-being during emergencies. Here are some key items to include:
#
# 1. **Water and Food:**
#    - At least a three-day supply of water (one gallon per person per day).
#    - Non-perishable food items (canned goods, granola bars, dried fruits, etc.) that are easy to open and consume.
#
# 2. **Medications:**
#    - A supply of prescription medications (at least a week's worth).
#    - Over-the-counter medications (pain relievers, antacids, etc.).
#    - A list of all medications, dosages, and any allergies.
#
# 3. **Medical Supplies:**
#    - First aid kit (band-aids, antiseptic wipes, gauze, etc.).
#    - Any necessary medical equipment (e.g., cane, walker, hearing aids, glasses).
#    - Extra batteries for hearing aids or other devices.
#
# 4. **Personal Care Items:**
#    - Hygiene products (toothbrush, toothpaste, soap, hand sanitizer, etc.).
#    - Incontinence supplies if needed.
#
# 5. **Communication Tools:**
#    - A fully charged cell phone with a portable charger.
#    - A list of emergency contacts, including family members and caregivers.
#    - A whistle to signal for help.
#
# 6. **Important Documents:**
#    - Copies of identification (driver’s license, Medicare card).
#    - Emergency contact information.
#    - Medical records and insurance information.
#
# 7. **Comfort Items:**
#    - A blanket or sleeping bag.
#    - A flashlight with extra batteries.
#    - A radio (battery-operated or hand-crank) for news updates.
#
# 8. **Cash:**
#    - Small denominations of cash, as ATMs may not be accessible during emergencies.
#
# 9. **Transportation:**
#    - A list of accessible transportation options in case evacuation is necessary.
#
# 10. **Special Needs Items:**
#     - Items specific to individual needs (e.g., oxygen tanks, special dietary foods).
#
# 11. **Emergency Plan:**
#     - A written emergency plan that includes evacuation routes, meeting places, and how to communicate with family members.
#
# 12. **Pet Supplies:**
#     - If applicable, include food, water, and supplies for pets.
#
# It's important to regularly check and update the kit, ensuring that food and medications are not expired and that all items are in good condition. Additionally, older adults should be familiar with the contents of their emergency kit and have a plan in place for how to use it.
# TRUE: Pack water, non-perishable food, medications, extra batteries, flashlight, important documents (insurance, IDs), pet supplies, a first aid kit, and a written list of your medications and contacts.
# Error Score: 0.0
#
# Q: How can older adults engage their support network for disaster preparedness?
# AI: Engaging a support network for disaster preparedness is crucial for older adults, as they may face unique challenges during emergencies. Here are several strategies to help them effectively involve their support network:
#
# 1. **Identify Support Network**: Encourage older adults to identify family members, friends, neighbors, and community organizations that can provide assistance during a disaster.
#
# 2. **Communication Plan**: Help them establish a clear communication plan. This includes sharing contact information, preferred methods of communication, and any specific needs or concerns they may have.
#
# 3. **Education and Training**: Organize workshops or informational sessions with their support network to educate everyone about disaster preparedness. This can include training on first aid, emergency response, and how to use emergency supplies.
#
# 4. **Create a Disaster Plan**: Work together to develop a personalized disaster preparedness plan. This should include evacuation routes, emergency contacts, medical needs, and a list of essential supplies.
#
# 5. **Regular Check-Ins**: Encourage regular check-ins with their support network to discuss preparedness plans and make updates as necessary. This can help ensure everyone is on the same page and ready to act.
#
# 6. **Practice Drills**: Conduct practice drills with their support network to ensure everyone knows their roles and responsibilities during a disaster. This can help reduce anxiety and improve response times.
#
# 7. **Resource Sharing**: Share resources such as emergency kits, information on local shelters, and community services that can assist during a disaster. This can help older adults feel more secure knowing they have access to necessary resources.
#
# 8. **Utilize Technology**: Encourage the use of technology for communication and information sharing. This can include group messaging apps, social media, or emergency alert systems to keep everyone informed.
#
# 9. **Involve Local Organizations**: Connect with local organizations that focus on disaster preparedness for older adults. These organizations can provide additional resources, training, and support.
#
# 10. **Encourage Community Engagement**: Promote participation in community preparedness events or volunteer opportunities. This can help older adults feel more connected and supported within their community.
#
# 11. **Address Mobility and Accessibility**: Discuss any mobility or accessibility issues with their support network to ensure that plans accommodate their specific needs during a disaster.
#
# 12. **Emotional Support**: Recognize the emotional aspect of disaster preparedness. Encourage open discussions about fears and concerns, and ensure that their support network is aware of how to provide emotional support during stressful times.
#
# By actively engaging their support network, older adults can enhance their disaster preparedness and ensure they have the necessary assistance and resources during emergencies.
# TRUE: Share your emergency plan with family, friends, neighbors, and caregivers. Make sure someone has a spare key and knows how to help with your medical equipment. Practice your plan together regularly.
# Error Score: 0.0
#
# Q: What special steps should older adults in rural areas take to prepare for disasters?
# AI: Older adults in rural areas face unique challenges when preparing for disasters due to factors like limited access to resources, healthcare, and transportation. Here are some special steps they can take to prepare:
#
# 1. **Create a Personal Emergency Plan**:
#    - Develop a comprehensive emergency plan that includes communication strategies, evacuation routes, and designated meeting places.
#    - Ensure that the plan is easy to understand and accessible.
#
# 2. **Build a Support Network**:
#    - Connect with neighbors, family, and friends to establish a support system. Regularly check in with each other, especially during emergencies.
#    - Consider joining local community groups or organizations focused on disaster preparedness.
#
# 3. **Stay Informed**:
#    - Sign up for local alerts and warnings through community emergency management systems.
#    - Keep a battery-operated or hand-crank radio to receive updates during power outages.
#
# 4. **Prepare an Emergency Kit**:
#    - Assemble a disaster supply kit that includes essential items such as medications, first aid supplies, water, non-perishable food, flashlight, batteries, and personal identification.
#    - Include items specific to individual needs, such as mobility aids or hearing devices.
#
# 5. **Plan for Transportation**:
#    - Identify reliable transportation options for evacuating if necessary. This may include arranging rides with neighbors or local services.
#    - Keep a list of local transportation services and their contact information.
#
# 6. **Consider Health Needs**:
#    - Maintain an updated list of medications, medical conditions, and healthcare providers. Share this information with trusted individuals.
#    - Ensure access to necessary medical equipment and supplies.
#
# 7. **Home Safety Modifications**:
#    - Make home modifications to enhance safety, such as securing heavy furniture, installing smoke detectors, and ensuring clear exit routes.
#    - Consider using technology, such as medical alert systems, for emergencies.
#
# 8. **Practice the Plan**:
#    - Regularly review and practice the emergency plan with family and friends to ensure everyone knows their roles and responsibilities.
#    - Conduct drills to familiarize everyone with evacuation routes and procedures.
#
# 9. **Stay Connected**:
#    - Use technology to stay connected with family and friends, especially during emergencies. Consider using social media or messaging apps for updates.
#    - Encourage family members to check in regularly, especially during severe weather or disaster warnings.
#
# 10. **Know Local Resources**:
#     - Familiarize yourself with local emergency services, shelters, and resources available in your community.
#     - Reach out to local agencies or organizations that provide assistance to older adults during disasters.
#
# 11. **Mental Health Preparedness**:
#     - Prepare for the emotional impact of disasters by having coping strategies in place. This may include mindfulness practices, access to counseling, or support groups.
#
# 12. **Review and Update Plans Regularly**:
#     - Regularly review and update emergency plans and kits to ensure they remain relevant and effective as circumstances change.
#
# By taking these steps, older adults in rural areas can enhance their preparedness for disasters and improve their resilience in the face of emergencies.
# TRUE: Stock up on supplies, arrange transportation options in advance, create a backup communications plan for power/internet outages, and build a network of neighbors who can help during emergencies.
# Error Score: 0.0
#
# Q: What steps should I take to create a family emergency communication plan?
# AI: Creating a family emergency communication plan is essential for ensuring that all family members know how to stay in touch and where to meet during an emergency. Here are the steps you can take to create an effective plan:
#
# ### 1. **Identify Emergency Scenarios**
#    - Consider the types of emergencies that could affect your family, such as natural disasters (earthquakes, floods, hurricanes), fires, medical emergencies, or other crises.
#
# ### 2. **Establish Communication Methods**
#    - **Primary Contact:** Designate a primary contact person outside the immediate area (like a relative or friend) who can help relay information.
#    - **Communication Tools:** Decide on the methods of communication (e.g., phone calls, text messages, social media, or messaging apps). Text messages may be more reliable than calls during emergencies.
#
# ### 3. **Create a Family Contact List**
#    - Compile a list of important phone numbers, including:
#      - Family members’ cell phones
#      - Work numbers
#      - School contacts
#      - Neighbors or nearby friends
#      - Emergency services (police, fire, medical)
#    - Ensure that everyone has a copy of this list, both in physical form and digitally.
#
# ### 4. **Designate Meeting Places**
#    - **Immediate Meeting Place:** Choose a safe location close to home where family members can gather if it’s safe to do so.
#    - **Alternative Meeting Place:** Select a secondary location further away in case the immediate area is unsafe or inaccessible.
#
# ### 5. **Establish Roles and Responsibilities**
#    - Assign specific roles to family members, such as who will grab emergency supplies, who will check on pets, or who will contact the primary contact person.
#
# ### 6. **Practice the Plan**
#    - Conduct regular drills to ensure everyone knows the plan and can execute it effectively. This helps to familiarize everyone with the steps to take during an emergency.
#
# ### 7. **Update the Plan Regularly**
#    - Review and update the communication plan at least once a year or whenever there are significant changes in your family (e.g., new phone numbers, moving, changes in family structure).
#
# ### 8. **Prepare for Different Scenarios**
#    - Consider how your plan might change based on different types of emergencies. For example, during a wildfire, you may need to evacuate quickly, while during a severe storm, you may need to stay put.
#
# ### 9. **Educate Family Members**
#    - Ensure that all family members, including children, understand the plan and know how to use the communication tools you’ve chosen.
#
# ### 10. **Keep Emergency Supplies Ready**
#    - Maintain an emergency kit that includes essential items like water, food, first aid supplies, flashlights, batteries, and a copy of your communication plan.
#
# ### 11. **Utilize Technology**
#    - Consider using apps designed for emergency communication and alerts. Some apps allow families to share their locations and communicate even when cell service is down.
#
# ### 12. **Stay Informed**
#    - Sign up for local emergency alerts and notifications to stay informed about potential threats in your area.
#
# By following these steps, you can create a comprehensive family emergency communication plan that helps ensure everyone knows what to do and how to stay connected during a crisis.
# TRUE: Start by talking with your family and support network about how you will contact each other and where to meet if separated. Keep a list of emergency contacts in your wallet and post important numbers near your phone. Use the Make a Plan Form from Ready.gov.
# Error Score: 0.0
#
# Q: How can I stay informed during a disaster if I don't have a smartphone?
# AI: Staying informed during a disaster without a smartphone can be challenging, but there are several effective methods you can use:
#
# 1. **Battery-Powered or Hand-Crank Radio**: Invest in a battery-powered or hand-crank emergency radio. These radios can receive NOAA Weather Radio broadcasts, which provide continuous updates on weather conditions and emergency information.
#
# 2. **Local News Radio Stations**: Tune in to local AM or FM radio stations that provide news updates. Many stations will cover emergency situations and provide important information.
#
# 3. **Television**: If you have access to a television, local news channels often provide live coverage and updates during disasters. Keep a battery-operated TV or a generator handy if you anticipate power outages.
#
# 4. **Community Alert Systems**: Check if your community has a local alert system that sends out notifications via landline phones or through sirens. Many communities have systems in place to alert residents of emergencies.
#
# 5. **Landline Phones**: Use a landline phone to call friends, family, or neighbors to get updates on the situation. They may have access to information that you do not.
#
# 6. **Public Libraries**: If it’s safe to do so, visit your local library. They often have access to news sources and may provide information on community resources during a disaster.
#
# 7. **Community Centers**: Local community centers or shelters may have information available and can serve as a hub for updates and resources.
#
# 8. **Word of Mouth**: Stay connected with neighbors and community members. They can share information and updates about the situation.
#
# 9. **Emergency Services**: Keep the contact numbers for local emergency services handy. They can provide information on what to do during a disaster.
#
# 10. **Prepare in Advance**: Before a disaster strikes, gather information about local emergency plans, evacuation routes, and resources. Create a communication plan with family and friends.
#
# By utilizing these methods, you can stay informed and make better decisions during a disaster, even without a smartphone.
# TRUE: Listen to local radio or television for emergency broadcasts. Consider purchasing a weather radio. Join local community groups or CERTs to receive alerts.
# Error Score: 0.0
#
# Q: What should I do if I am unable to evacuate during an emergency?
# AI: If you find yourself unable to evacuate during an emergency, it's important to stay calm and take the following steps to ensure your safety:
#
# 1. **Stay Informed**: Keep a battery-powered radio, smartphone, or other devices handy to receive updates from local authorities. Follow official instructions and updates regarding the emergency.
#
# 2. **Find a Safe Location**: Identify a safe area within your home or building. This could be a room with no windows or a higher floor if there is flooding. Make sure it is away from potential hazards.
#
# 3. **Prepare Your Shelter**: Gather essential supplies, including water, non-perishable food, a flashlight, batteries, a first aid kit, and any necessary medications. If you have pets, ensure you have supplies for them as well.
#
# 4. **Seal Off the Area**: If necessary, seal windows and doors with duct tape and plastic sheeting to protect against smoke, flooding, or other hazards. This can help keep out harmful elements.
#
# 5. **Signal for Help**: If you are in a situation where you cannot evacuate, make your presence known. Use a whistle, flashlight, or signal from a window to attract attention if rescue teams are nearby.
#
# 6. **Stay Low**: If there is smoke or gas, stay low to the ground where the air is clearer. Cover your mouth and nose with a cloth if necessary.
#
# 7. **Stay Together**: If you are with others, stay together and keep communication open. This can help maintain morale and ensure everyone is accounted for.
#
# 8. **Conserve Resources**: Ration your food and water supplies, and use your flashlight and other resources sparingly to ensure they last as long as possible.
#
# 9. **Prepare for Rescue**: If you hear rescuers, make noise to alert them to your location. If you are in a building, stay near a window or door where you can be seen.
#
# 10. **Stay Calm**: Panic can lead to poor decision-making. Focus on what you can control and take things one step at a time.
#
# Remember, every emergency is different, so adapt these steps to your specific situation. Always prioritize your safety and the safety of those around you.
# TRUE: Shelter in place in the safest room in your home, and inform your support network of your situation. Keep a radio or phone handy for updates from officials.
# Error Score: 0.0
#
# Q: What items should older adults include in an emergency preparedness kit?
# AI: Creating an emergency preparedness kit for older adults is essential to ensure their safety and well-being during emergencies. Here are some key items to include:
#
# 1. **Water and Food:**
#    - At least a three-day supply of water (one gallon per person per day).
#    - Non-perishable food items (canned goods, granola bars, dried fruits, etc.) that are easy to open and consume.
#
# 2. **Medications:**
#    - A supply of prescription medications (at least a week's worth).
#    - Over-the-counter medications (pain relievers, antacids, etc.).
#    - A list of all medications, dosages, and any allergies.
#
# 3. **Medical Supplies:**
#    - First aid kit (band-aids, antiseptic wipes, gauze, etc.).
#    - Any necessary medical equipment (e.g., cane, walker, hearing aids, glasses).
#    - Extra batteries for hearing aids or other devices.
#
# 4. **Personal Care Items:**
#    - Hygiene products (toothbrush, toothpaste, soap, hand sanitizer, etc.).
#    - Incontinence supplies if needed.
#
# 5. **Communication Tools:**
#    - A fully charged cell phone with a portable charger.
#    - A list of emergency contacts, including family members and caregivers.
#    - A whistle to signal for help.
#
# 6. **Important Documents:**
#    - Copies of identification (driver’s license, Medicare card).
#    - Emergency contact information.
#    - Medical records and insurance information.
#
# 7. **Comfort Items:**
#    - A blanket or sleeping bag.
#    - A flashlight with extra batteries.
#    - A radio (battery-operated or hand-crank) for updates.
#
# 8. **Cash:**
#    - Small denominations of cash, as ATMs may not be accessible during emergencies.
#
# 9. **Transportation Needs:**
#    - A list of accessible transportation options in the area.
#    - A mobility device if needed (e.g., wheelchair, scooter).
#
# 10. **Special Considerations:**
#     - Items for pets if applicable (food, water, leash).
#     - Any specific items related to personal hobbies or interests that may provide comfort.
#
# 11. **Emergency Plan:**
#     - A written emergency plan that includes evacuation routes, meeting places, and how to communicate with family members.
#
# It's important to regularly check and update the kit, ensuring that food and medications are not expired and that all items are in good condition. Additionally, older adults should be familiar with the contents of their kit and have a plan for how to use it in case of an emergency.
# TRUE: Pack water, non-perishable food, medications, extra batteries, flashlight, important documents (insurance, IDs), pet supplies, a first aid kit, and a written list of your medications and contacts.
# Error Score: 0.0
#
# Q: How can older adults engage their support network for disaster preparedness?
# AI: Engaging a support network for disaster preparedness is crucial for older adults, as they may face unique challenges during emergencies. Here are several strategies to help older adults effectively engage their support network:
#
# 1. **Identify Key Contacts**: Encourage older adults to identify family members, friends, neighbors, and community organizations that can provide assistance during a disaster.
#
# 2. **Create a Communication Plan**: Help them develop a communication plan that includes phone numbers, email addresses, and social media contacts. Ensure they know how to reach their support network in case of an emergency.
#
# 3. **Organize Meetings**: Facilitate regular meetings with their support network to discuss disaster preparedness plans, share resources, and review emergency contacts. This can be done in person or virtually.
#
# 4. **Educate on Preparedness**: Provide information on disaster preparedness, including creating emergency kits, evacuation plans, and understanding local hazards. Encourage older adults to share this information with their support network.
#
# 5. **Practice Drills**: Organize practice drills with their support network to ensure everyone knows their roles and responsibilities during a disaster. This can help build confidence and familiarity with the plan.
#
# 6. **Utilize Technology**: Encourage the use of technology, such as group messaging apps or social media, to keep everyone informed and connected. This can be especially useful for quick updates during an emergency.
#
# 7. **Leverage Community Resources**: Connect older adults with local organizations that focus on disaster preparedness, such as community centers, senior organizations, or local emergency management agencies.
#
# 8. **Encourage Mutual Aid**: Promote the idea of mutual aid within their support network, where members can offer assistance to one another, such as helping with transportation, providing supplies, or checking in during emergencies.
#
# 9. **Discuss Mobility and Accessibility**: Address any mobility or accessibility concerns that older adults may have and ensure their support network is aware of these needs when planning for emergencies.
#
# 10. **Stay Informed**: Encourage older adults to stay informed about local disaster plans and resources, and share this information with their support network to ensure everyone is on the same page.
#
# 11. **Create a Buddy System**: Establish a buddy system where older adults are paired with someone in their support network who can check on them during emergencies and assist as needed.
#
# 12. **Encourage Regular Check-Ins**: Suggest that older adults and their support network establish a routine for regular check-ins, especially during severe weather or other potential emergencies.
#
# By taking these steps, older adults can strengthen their support network and enhance their overall disaster preparedness, ensuring they have the assistance they need during emergencies.
# TRUE: Share your emergency plan with family, friends, neighbors, and caregivers. Make sure someone has a spare key and knows how to help with your medical equipment. Practice your plan together regularly.
# Error Score: 0.0
#
# Q: What special steps should older adults in rural areas take to prepare for disasters?
# AI: Older adults in rural areas face unique challenges when preparing for disasters due to factors such as limited access to resources, healthcare, and transportation. Here are some special steps they can take to prepare:
#
# 1. **Create a Personal Emergency Plan**:
#    - Develop a comprehensive emergency plan that includes communication methods, evacuation routes, and designated meeting places.
#    - Ensure that the plan is easy to understand and accessible.
#
# 2. **Build a Support Network**:
#    - Connect with neighbors, family, and friends to establish a support system. Regularly check in with each other, especially during emergencies.
#    - Join local community groups or organizations that focus on disaster preparedness.
#
# 3. **Stay Informed**:
#    - Sign up for local alerts and warnings through community emergency management systems.
#    - Keep a battery-operated or hand-crank radio to receive updates during power outages.
#
# 4. **Prepare an Emergency Kit**:
#    - Assemble a disaster supply kit that includes essential items such as medications, first aid supplies, non-perishable food, water, flashlight, batteries, and personal hygiene items.
#    - Include important documents (e.g., identification, medical records) in a waterproof container.
#
# 5. **Plan for Medical Needs**:
#    - Ensure an adequate supply of medications and medical supplies, and have a plan for accessing healthcare during a disaster.
#    - Consider a medical alert system for emergencies.
#
# 6. **Transportation Arrangements**:
#    - Identify reliable transportation options for evacuating if necessary. This may include arranging rides with neighbors or local services.
#    - Keep a list of local transportation services that can assist during emergencies.
#
# 7. **Home Safety Modifications**:
#    - Make necessary modifications to the home to enhance safety, such as securing heavy furniture, installing smoke detectors, and ensuring clear escape routes.
#    - Consider backup power sources, such as generators, for medical equipment.
#
# 8. **Practice Drills**:
#    - Conduct regular emergency drills to ensure familiarity with the plan and to identify any areas that need improvement.
#    - Involve family members or caregivers in these drills.
#
# 9. **Stay Connected**:
#    - Use technology to stay connected with family and friends. Regular check-ins can provide emotional support and ensure safety.
#    - Consider using social media or messaging apps to share information quickly.
#
# 10. **Know Local Resources**:
#     - Familiarize yourself with local emergency services, shelters, and resources available in the community.
#     - Keep a list of contact numbers for local emergency services, neighbors, and family members.
#
# 11. **Mental Health Preparedness**:
#     - Prepare for the emotional impact of disasters by having coping strategies in place. This may include mindfulness practices, access to counseling, or support groups.
#
# 12. **Community Involvement**:
#     - Participate in local disaster preparedness workshops or training sessions to learn more about specific risks and response strategies in the area.
#
# By taking these steps, older adults in rural areas can enhance their preparedness for disasters and improve their resilience in the face of emergencies.
# TRUE: Stock up on supplies, arrange transportation options in advance, create a backup communications plan for power/internet outages, and build a network of neighbors who can help during emergencies.
# Error Score: 0.0
